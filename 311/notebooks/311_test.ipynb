# %%
import requests
import os
import datetime as dt
import json
from dotenv import load_dotenv
from google.cloud import storage

# %%
load_dotenv()
# Out:
# True

# %%
query_date = str(dt.date.today() - dt.timedelta(days= 2))

url = f"https://data.sfgov.org/resource/vw6y-z8j6.json?$where=updated_datetime>='{query_date}'&$limit=999999"
response = requests.get(url)
items = response.json()

# %%
bucket_name = os.environ.get("GCS_BUCKET_NAME")
service_acct = os.environ.get("GCS_BUCKET_CREDENTIALS")

client = storage.Client.from_service_account_json(service_acct)
bucket = client.bucket(bucket_name)

json_data = json.dumps(items, indent=4)

blob = bucket.blob(f'{query_date}_311_api_call')
blob.upload_from_string(json_data)

# %%
json_name = f'{query_date}_311_api_call'

json_string = blob.download_as_text()
json_try = json.loads(json_string)

# %%
json_try
# Out:
# [{'service_request_id': '101004198396',
#   'requested_datetime': '2026-06-05T22:27:34.000',
#   'updated_datetime': '2026-06-06T00:00:04.000',
#   'status_description': 'Open',
#   'status_notes': 'open',
#   'agency_responsible': 'RPD - Park Service Area 6',
#   'service_name': 'RPD General',
#   'service_subtype': 'park_services_area',
#   'service_details': 'irrigation',
#   'address': 'Mission Playground I POI, SAN FRANCISCO, CA 94110',
#   'supervisor_district': '8.0',
#   'neighborhoods_sffind_boundaries': 'Mission Dolores',
#   'analysis_neighborhood': 'Mission',
#   'police_district': 'MISSION',
#   'lat': '37.759291467',
#   'long': '-122.4223013',
#   'point': {'latitude': '37.759291467',
#    'longitude': '-122.4223013',
#    'human_address': '{"address": "", "city": "", "state": "", "zip": ""}'},
#   'point_geom': {'type': 'Point', 'coordinates': [-122.4223013, 37.759291467]},
#   'source': 'Phone',
#   'data_as_of': '2026-06-08T01:00:00.000',
#   'data_loaded_at': '2026-06-08T03:13:41.000'},
#  {'service_request_id': '101004198555',
#   'requested_datetime': '2026-06-06T00:11:53.000',
#   'updated_datetime': '2026-06-06T00:15:45.000',
#   'status_description': 'Open',
#   'status_notes': 'open',
#   'agency_responsible': 'RPD - Community Gardens',
#   'service_name': 'RPD General',
#   'service_subtype': 'park_services_area',
#   'service_details': 'trash_dumping',
#   'address': '780 SAN BRUNO AVE, SAN FRANCISCO, CA 94107',
#   'street': 'SAN BRUNO AVE',
#   'supervisor_district': '10.0',
#   'neighborhoods_sffind_boundaries': 'Potrero Hill',
#   'analysis_neighborhood': 'Potrero Hill',
#   'police_district': 'BAYVIEW',
#   'lat': '37.75973000000002',
#   'long': '-122.40512833333337',
#   'point': {'latitude': '37.75973000000002',
#    'longitude': '-122.40512833333337',
#    'human_address': '{"address": "", "city": "", "state": "", "zip": ""}'},
#   'point_geom': {'type': 'Point', 'coordinates': [-122.405128333, 37.75973]},
#   'source': 'Mobile',
#   'media_url': {'url': 'https://spot-sf-res.cloudinary.com/image/upload/v1780729910/san-francisco/production/ivm8bi9sqbq8rnwupk4m.jpg'},
#   'data_as_of': '2026-06-08T01:00:00.000',
#   'data_loaded_at': '2026-06-08T03:13:41.000'},
#  {'service_request_id': '101004198557',
#   'requested_datetime': '2026-06-06T00:15:02.000',
#   'updated_datetime': '2026-06-06T00:24:35.000',
#   'status_description': 'Open',
#   'status_notes': 'open',
#   'agency_responsible': 'MTA - Muni Feedback Received',
#   'service_name': 'Muni Employee Feedback',
#   'service_subtype': 'praise_employee',
#   'service_details': 'praise_employee',
#   'address': 'INTERSECTION MARKET ST, MONTGOMERY ST, SAN FRANCISCO, CA 94104',
#   'street': 'MARKET ST',
#   'supervisor_district': '6.0',
#   'neighborhoods_sffind_boundaries': 'South of Market',
#   'analysis_neighborhood': 'Financial District/South Beach',
#   'police_district': 'CENTRAL',
#   'lat': '37.7887210259',
#   'long': '-122.4020657735',
#   'point': {'latitude': '37.7887210259',
#    'longitude': '-122.4020657735',
#    'human_address': '{"address": "", "city": "", "state": "", "zip": ""}'},
#   'point_geom': {'type': 'Point',
#    'coordinates': [-122.402065773, 37.788721026]},
#   'source': 'Phone',
#   'data_as_of': '2026-06-08T01:00:00.000',
#   'data_loaded_at': '2026-06-08T03:13:41.000'},
#  {'service_request_id': '101004198569',
#   'requested_datetime': '2026-06-06T00:25:51.000',
#   'updated_datetime': '2026-06-06T00:25:58.000',
#   'status_description': 'Open',
#   'status_notes': 'open',
#   'agency_responsible': 'Noise Report',
#   'service_name': 'Noise',
#   'service_subtype': 'other_excessive_noise',
#   'address': '11 BRADY ST, SAN FRANCISCO, CA 94103',
#   'street': 'BRADY ST',
#   'supervisor_district': '6.0',
#   'neighborhoods_sffind_boundaries': 'South of Market',
#   'analysis_neighborhood': 'Mission',
#   'police_district': 'SOUTHERN',
#   'lat': '37.77341782023014',
#   'long': '-122.42087477061264',
#   'point': {'latitude': '37.77341782023014',
#    'longitude': '-122.42087477061264',
#    'human_address': '{"address": "", "city": "", "state": "", "zip": ""}'},
#   'point_geom': {'type': 'Point',
#    'coordinates': [-122.420874771, 37.77341782]},
#   'source': 'Mobile',
#   'media_url': {'url': 'https://spot-sf-res.cloudinary.com/image/upload/v1780730750/san-francisco/production/sfvv4hysr7wnnqtihxnj.jpg'},
#   'data_as_of': '2026-06-08T01:00:00.000',
#   'data_loaded_at': '2026-06-08T03:13:41.000'},
#  {'service_request_id': '101004198570',
#   'requested_datetime': '2026-06-06T00:27:02.000',
#   'updated_datetime': '2026-06-06T00:27:15.000',
#   'status_description': 'Open',
#   'status_notes': 'open',
#   'agency_responsible': 'DPH Environmental Health - Noise',
#   'service_name': 'Noise',
#   'service_subtype': 'mechanical_equipment',
#   'address': '571 GEARY ST, SAN FRANCISCO, CA 94102',
#   'street': 'GEARY ST',
#   'supervisor_district': '5.0',
#   'neighborhoods_sffind_boundaries': 'Tenderloin',
#   'analysis_neighborhood': 'Tenderloin',
#   'police_district': 'CENTRAL',
#   'lat': '37.78654537849893',
#   'long': '-122.41243835538627',
#   'point': {'latitude': '37.78654537849893',
#    'longitude': '-122.41243835538627',
#    'human_address': '{"address": "", "city": "", "state": "", "zip": ""}'},
#   'point_geom': {'type': 'Point',
#    'coordinates': [-122.412438355, 37.786545378]},
#   'source': 'Mobile',
#   'data_as_of': '2026-06-08T01:00:00.000',
#   'data_loaded_at': '2026-06-08T03:13:41.000'},
#  {'service_request_id': '101004198561',
#   'requested_datetime': '2026-06-06T00:19:02.000',
#   'updated_datetime': '2026-06-06T00:40:39.000',
#   'status_description': 'Open',
#   'status_notes': 'open',
#   'agency_responsible': 'PW - Street Use and Mapping',
#   'service_name': 'General Request',
#   'service_subtype': 'public_works',
#   'service_details': 'bsm request_for_service',
#   'address': '1467 25TH AVE, SAN FRANCISCO, CA 94122',
#   'street': '25TH AVE',
#   'supervisor_district': '4.0',
#   'neighborhoods_sffind_boundaries': 'Outer Sunset',
#   'analysis_neighborhood': 'Sunset/Parkside',
#   'police_district': 'TARAVAL',
#   'lat': '37.76016977',
#   'long': '-122.48347433',
#   'point': {'latitude': '37.76016977',
#    'longitude': '-122.48347433',
#    'human_address': '{"address": "", "city": "", "state": "", "zip": ""}'},
#   'point_geom': {'type': 'Point', 'coordinates': [-122.48347433, 37.76016977]},
#   'source': 'Web',
#   'media_url': {'url': 'https://sanfrancisco.form.us.empro.verintcloudservices.com/form/auto/download_attachments?caseid=101004198561&formref=97M0XYC9'},
#   'data_as_of': '2026-06-08T01:00:00.000',
#   'data_loaded_at': '2026-06-08T03:13:41.000'},
#  {'service_request_id': '101004198545',
#   'requested_datetime': '2026-06-06T00:00:51.000',
#   'updated_datetime': '2026-06-06T00:45:28.000',
#   'status_description': 'Open',
#   'status_notes': 'open',
#   'agency_responsible': 'PW - Street Use and Mapping',
#   'service_name': 'Sidewalk and Curb',
#   'service_subtype': 'other',
#   'address': '201 BERRY ST, SAN FRANCISCO, CA 94158',
#   'street': 'BERRY ST',
#   'supervisor_district': '6.0',
#   'neighborhoods_sffind_boundaries': 'Mission Bay',
#   'analysis_neighborhood': 'Mission Bay',
#   'police_district': 'SOUTHERN',
#   'lat': '37.77568510829138',
#   'long': '-122.39333421036334',
#   'point': {'latitude': '37.77568510829138',
#    'longitude': '-122.39333421036334',
#    'human_address': '{"address": "", "city": "", "state": "", "zip": ""}'},
#   'point_geom': {'type': 'Point',
#    'coordinates': [-122.39333421, 37.775685108]},
#   'source': 'Mobile',
#   'data_as_of': '2026-06-08T01:00:00.000',
#   'data_loaded_at': '2026-06-08T03:13:41.000'},
#  {'service_request_id': '101004198585',
#   'requested_datetime': '2026-06-06T00:35:55.000',
#   'updated_datetime': '2026-06-06T00:46:52.000',
#   'status_description': 'Open',
#   'status_notes': 'in progress',
#   'agency_responsible': 'PW - Street and Environmental Services',
#   'service_name': 'Litter Receptacle Maintenance',
#   'service_subtype': 'remove_garbage_can',
#   'address': '3370 19TH ST, SAN FRANCISCO, CA 94110',
#   'street': '19TH ST',
#   'supervisor_district': '9.0',
#   'neighborhoods_sffind_boundaries': 'Mission',
#   'analysis_neighborhood': 'Mission',
#   'police_district': 'MISSION',
#   'lat': '37.7603864',
#   'long': '-122.41852906',
#   'point': {'latitude': '37.7603864',
#    'longitude': '-122.41852906',
#    'human_address': '{"address": "", "city": "", "state": "", "zip": ""}'},
#   'point_geom': {'type': 'Point', 'coordinates': [-122.41852906, 37.7603864]},
#   'source': 'Phone',
#   'data_as_of': '2026-06-08T01:00:00.000',
#   'data_loaded_at': '2026-06-08T03:13:41.000'},
#  {'service_request_id': '101004198560',
#   'requested_datetime': '2026-06-06T00:19:02.000',
#   'updated_datetime': '2026-06-06T00:51:54.000',
#   'status_description': 'Open',
#   'status_notes': 'accepted',
#   'agency_responsible': 'PW - Street and Environmental Services',
#   'service_name': 'Litter Receptacle Maintenance',
#   'service_subtype': 'toters_left_out_24x7',
#   'address': '1467 25TH AVE, SAN FRANCISCO, CA 94122',
#   'street': '25TH AVE',
#   'supervisor_district': '4.0',
#   'neighborhoods_sffind_boundaries': 'Outer Sunset',
#   'analysis_neighborhood': 'Sunset/Parkside',
#   'police_district': 'TARAVAL',
#   'lat': '37.76016977',
#   'long': '-122.48347433',
#   'point': {'latitude': '37.76016977',
#    'longitude': '-122.48347433',
#    'human_address': '{"address": "", "city": "", "state": "", "zip": ""}'},
#   'point_geom': {'type': 'Point', 'coordinates': [-122.48347433, 37.76016977]},
#   'source': 'Web',
#   'media_url': {'url': 'https://sanfrancisco.form.us.empro.verintcloudservices.com/form/auto/download_attachments?caseid=101004198560&formref=Q351H4D5'},
#   'data_as_of': '2026-06-08T01:00:00.000',
#   'data_loaded_at': '2026-06-08T03:13:41.000'},
#  {'service_request_id': '101004198544',
#   'requested_datetime': '2026-06-05T23:58:56.000',
#   'updated_datetime': '2026-06-06T01:06:45.000',
#   'status_description': 'Open',
#   'status_notes': 'new',
#   'agency_responsible': 'MTA - Traffic Signal',
#   'service_name': 'Damage Property',
#   'service_subtype': 'traffic_signal',
#   'address': 'INTERSECTION CORTLAND AVE, BAY SHORE BLVD, SAN FRANCISCO, CA 94124',
#   'street': 'CORTLAND AVE',
#   'supervisor_district': '10.0',
#   'neighborhoods_sffind_boundaries': 'Apparel City',
#   'analysis_neighborhood': 'Bayview Hunters Point',
#   'police_district': 'BAYVIEW',
#   'lat': '37.7395661402',
#   'long': '-122.4069784496',
#   'point': {'latitude': '37.7395661402',
#    'longitude': '-122.4069784496',
#    'human_address': '{"address": "", "city": "", "state": "", "zip": ""}'},
#   'point_geom': {'type': 'Point', 'coordinates': [-122.40697845, 37.73956614]},
#   'source': 'Phone',
#   'data_as_of': '2026-06-08T01:00:00.000',
#   'data_loaded_at': '2026-06-08T03:13:41.000'},
#  {'service_request_id': '101004198602',
#   'requested_datetime': '2026-06-06T01:06:20.000',
#   'updated_datetime': '2026-06-06T01:06:49.000',
#   'status_description': 'Open',
#   'status_notes': 'open',
#   'agency_responsible': 'DPH Environmental Health - Noise',
#   'service_name': 'Noise',
#   'service_subtype': 'mechanical_equipment',
#   'address': '34 SHANNON ST, SAN FRANCISCO, CA 94102',
#   'street': 'SHANNON ST',
#   'supervisor_district': '5.0',
#   'neighborhoods_sffind_boundaries': 'Tenderloin',
#   'analysis_neighborhood': 'Tenderloin',
#   'police_district': 'TENDERLOIN',
#   'lat': '37.78647860644197',
#   'long': '-122.41214733570814',
#   'point': {'latitude': '37.78647860644197',
#    'longitude': '-122.41214733570814',
#    'human_address': '{"address": "", "city": "", "state": "", "zip": ""}'},
#   'point_geom': {'type': 'Point',
#    'coordinates': [-122.412147336, 37.786478606]},
#   'source': 'Mobile',
#   'data_as_of': '2026-06-08T01:00:00.000',
#   'data_loaded_at': '2026-06-08T03:13:41.000'},
#  {'service_request_id': '101004198605',
#   'requested_datetime': '2026-06-06T01:07:52.000',
#   'updated_datetime': '2026-06-06T01:07:53.000',
#   'status_description': 'Open',
#   'status_notes': 'open',
#   'agency_responsible': 'Noise Report',
#   'service_name': 'Noise',
#   'service_subtype': 'other_excessive_noise',
#   'address': 'Mission Playground I POI, SAN FRANCISCO, CA 94110',
#   'supervisor_district': '8.0',
#   'neighborhoods_sffind_boundaries': 'Mission Dolores',
#   'analysis_neighborhood': 'Mission',
#   'police_district': 'MISSION',
#   'lat': '37.759291467',
#   'long': '-122.4223013',
#   'point': {'latitude': '37.759291467',
#    'longitude': '-122.4223013',
#    'human_address': '{"address": "", "city": "", "state": "", "zip": ""}'},
#   'point_geom': {'type': 'Point', 'coordinates': [-122.4223013, 37.759291467]},
#   'source': 'Web',
#   'data_as_of': '2026-06-08T01:00:00.000',
#   'data_loaded_at': '2026-06-08T03:13:41.000'},
#  {'service_request_id': '101004198461',
#   'requested_datetime': '2026-06-05T22:52:38.000',
#   'closed_date': '2026-06-06T02:16:47.000',
#   'updated_datetime': '2026-06-06T01:16:50.000',
#   'status_description': 'Closed',
#   'status_notes': 'Case Resolved - Officer responded to request under CAD # 261563512. Unable to Locate.',
#   'agency_responsible': 'MTA - Parking Enforcement Dispatch',
#   'service_name': 'Parking Enforcement',
#   'service_subtype': 'blocking_driveway_cite_only',
#   'address': '1351 PAGE ST, SAN FRANCISCO, CA 94117',
#   'street': 'PAGE ST',
#   'supervisor_district': '5.0',
#   'neighborhoods_sffind_boundaries': 'Buena Vista',
#   'analysis_neighborhood': 'Haight Ashbury',
#   'police_district': 'PARK',
#   'lat': '37.77132826908055',
#   'long': '-122.44303900748491',
#   'point': {'latitude': '37.77132826908055',
#    'longitude': '-122.44303900748491',
#    'human_address': '{"address": "", "city": "", "state": "", "zip": ""}'},
#   'point_geom': {'type': 'Point',
#    'coordinates': [-122.443039007, 37.771328269]},
#   'source': 'Mobile',
#   'media_url': {'url': 'https://spot-sf-res.cloudinary.com/image/upload/v1780725158/san-francisco/production/hxw9xzcrazda3lrpjnym.jpg'},
#   'data_as_of': '2026-06-08T01:00:00.000',
#   'data_loaded_at': '2026-06-08T03:13:41.000'},
#  {'service_request_id': '101004191996',
#   'requested_datetime': '2026-06-04T22:22:38.000',
#   'closed_date': '2026-06-05T01:22:00.000',
#   'updated_datetime': '2026-06-06T01:17:04.000',
#   'status_description': 'Closed',
#   'status_notes': 'Case Resolved - Completed',
#   'agency_responsible': 'PW - Street and Environmental Services',
#   'service_name': 'Street and Sidewalk Cleaning',
#   'service_subtype': 'garbage_and_debris',
#   'service_details': 'transit_shelter_platform',
#   'address': '3491 CESAR CHAVEZ ST, SAN FRANCISCO, CA 94110',
#   'street': 'CESAR CHAVEZ ST',
#   'supervisor_district': '9.0',
#   'neighborhoods_sffind_boundaries': 'Bernal Heights',
#   'analysis_neighborhood': 'Bernal Heights',
#   'police_district': 'MISSION',
#   'lat': '37.748033160070676',
#   'long': '-122.4200630619689',
#   'point': {'latitude': '37.748033160070676',
#    'longitude': '-122.4200630619689',
#    'human_address': '{"address": "", "city": "", "state": "", "zip": ""}'},
#   'point_geom': {'type': 'Point',
#    'coordinates': [-122.420063062, 37.74803316]},
#   'source': 'Mobile',
#   'media_url': {'url': 'https://spot-sf-res.cloudinary.com/image/upload/v1780636957/san-francisco/production/hqcncl4g9pfstuvt9d1c.jpg'},
#   'data_as_of': '2026-06-08T01:00:00.000',
#   'data_loaded_at': '2026-06-08T03:13:41.000'},
#  {'service_request_id': '101004124921',
#   'requested_datetime': '2026-05-25T14:59:54.000',
#   'updated_datetime': '2026-06-06T01:19:32.000',
#   'status_description': 'Open',
#   'status_notes': 'in progress',
#   'agency_responsible': 'PW - Street and Environmental Services',
#   'service_name': 'Street and Sidewalk Cleaning',
#   'service_subtype': 'garbage_and_debris',
#   'service_details': 'other_loose_garbage_debris_yard_waste',
#   'address': '3368 19TH ST, SAN FRANCISCO, CA 94110',
#   'street': '19TH ST',
#   'supervisor_district': '9.0',
#   'neighborhoods_sffind_boundaries': 'Mission',
#   'analysis_neighborhood': 'Mission',
#   'police_district': 'MISSION',
#   'lat': '37.76040407',
#   'long': '-122.41860143',
#   'point': {'latitude': '37.76040407',
#    'longitude': '-122.41860143',
#    'human_address': '{"address": "", "city": "", "state": "", "zip": ""}'},
#   'point_geom': {'type': 'Point', 'coordinates': [-122.41860143, 37.76040407]},
#   'source': 'Web',
#   'media_url': {'url': 'https://sanfrancisco.form.us.empro.verintcloudservices.com/form/auto/download_attachments?caseid=101004124921&formref=UMI466O3'},
#   'data_as_of': '2026-06-08T01:00:00.000',
#   'data_loaded_at': '2026-06-08T03:13:41.000'},
#  {'service_request_id': '101004198620',
#   'requested_datetime': '2026-06-06T01:20:46.000',
#   'updated_datetime': '2026-06-06T01:20:53.000',
#   'status_description': 'Open',
#   'status_notes': 'new',
#   'agency_responsible': 'Recology - Litter',
#   'service_name': 'Litter Receptacle Maintenance',
#   'service_subtype': 'other_including_abandoned_toter',
#   'address': '3370 19TH ST, SAN FRANCISCO, CA 94110',
#   'street': '19TH ST',
#   'supervisor_district': '9.0',
#   'neighborhoods_sffind_boundaries': 'Mission',
#   'analysis_neighborhood': 'Mission',
#   'police_district': 'MISSION',
#   'lat': '37.7603864',
#   'long': '-122.41852906',
#   'point': {'latitude': '37.7603864',
#    'longitude': '-122.41852906',
#    'human_address': '{"address": "", "city": "", "state": "", "zip": ""}'},
#   'point_geom': {'type': 'Point', 'coordinates': [-122.41852906, 37.7603864]},
#   'source': 'Phone',
#   'data_as_of': '2026-06-08T01:00:00.000',
#   'data_loaded_at': '2026-06-08T03:13:41.000'},
#  {'service_request_id': '101004198622',
#   'requested_datetime': '2026-06-06T01:31:30.000',
#   'updated_datetime': '2026-06-06T01:31:30.000',
#   'status_description': 'Open',
#   'status_notes': 'open',
#   'agency_responsible': 'Noise Report',
#   'service_name': 'Noise',
#   'service_subtype': 'amplified_sound_electronics',
#   'address': '3138 FILLMORE ST, SAN FRANCISCO, CA 94123',
#   'street': 'FILLMORE ST',
#   'supervisor_district': '2.0',
#   'neighborhoods_sffind_boundaries': 'Union Street',
#   'analysis_neighborhood': 'Marina',
#   'police_district': 'NORTHERN',
#   'lat': '37.79869112',
#   'long': '-122.43565465',
#   'point': {'latitude': '37.79869112',
#    'longitude': '-122.43565465',
#    'human_address': '{"address": "", "city": "", "state": "", "zip": ""}'},
#   'point_geom': {'type': 'Point', 'coordinates': [-122.43565465, 37.79869112]},
#   'source': 'Web',
#   'data_as_of': '2026-06-08T01:00:00.000',
#   'data_loaded_at': '2026-06-08T03:13:41.000'},
#  {'service_request_id': '101004198623',
#   'requested_datetime': '2026-06-06T01:33:06.000',
#   'updated_datetime': '2026-06-06T01:33:07.000',
#   'status_description': 'Open',
#   'status_notes': 'open',
#   'agency_responsible': 'Noise Report',
#   'service_name': 'Noise',
#   'service_subtype': 'amplified_sound_electronics',
#   'address': '3138 FILLMORE ST, SAN FRANCISCO, CA 94123',
#   'street': 'FILLMORE ST',
#   'supervisor_district': '2.0',
#   'neighborhoods_sffind_boundaries': 'Union Street',
#   'analysis_neighborhood': 'Marina',
#   'police_district': 'NORTHERN',
#   'lat': '37.79869112',
#   'long': '-122.43565465',
#   'point': {'latitude': '37.79869112',
#    'longitude': '-122.43565465',
#    'human_address': '{"address": "", "city": "", "state": "", "zip": ""}'},
#   'point_geom': {'type': 'Point', 'coordinates': [-122.43565465, 37.79869112]},
#   'source': 'Web',
#   'data_as_of': '2026-06-08T01:00:00.000',
#   'data_loaded_at': '2026-06-08T03:13:41.000'},
#  {'service_request_id': '101004198240',
#   'requested_datetime': '2026-06-05T21:24:52.000',
#   'updated_datetime': '2026-06-06T01:51:55.000',
#   'status_description': 'Open',
#   'status_notes': 'accepted',
#   'agency_responsible': 'PW - Urban Forestry',
#   'service_name': 'Tree Maintenance',
#   'service_subtype': 'damaged_tree',
#   'service_details': 'fallen_tree',
#   'address': '201 HOLYOKE ST, SAN FRANCISCO, CA 94134',
#   'street': 'HOLYOKE ST',
#   'supervisor_district': '9.0',
#   'neighborhoods_sffind_boundaries': 'Portola',
#   'analysis_neighborhood': 'Portola',
#   'police_district': 'BAYVIEW',
#   'lat': '37.72865867336437',
#   'long': '-122.40947484970093',
#   'point': {'latitude': '37.72865867336437',
#    'longitude': '-122.40947484970093',
#    'human_address': '{"address": "", "city": "", "state": "", "zip": ""}'},
#   'point_geom': {'type': 'Point',
#    'coordinates': [-122.40947485, 37.728658673]},
#   'source': 'Mobile',
#   'media_url': {'url': 'https://spot-sf-res.cloudinary.com/image/upload/v1780719891/san-francisco/production/ovjk4ofdgmrzvstpawln.jpg'},
#   'data_as_of': '2026-06-08T01:00:00.000',
#   'data_loaded_at': '2026-06-08T03:13:41.000'},
#  {'service_request_id': '101004193318',
#   'requested_datetime': '2026-06-05T08:44:53.000',
#   'updated_datetime': '2026-06-06T02:21:53.000',
#   'status_description': 'Open',
#   'status_notes': 'in progress',
#   'agency_responsible': 'PW - Street and Environmental Services',
#   'service_name': 'Street and Sidewalk Cleaning',
#   'service_subtype': 'garbage_and_debris',
#   'service_details': 'other_loose_garbage_debris_yard_waste',
#   'address': '575 10TH ST, SAN FRANCISCO, CA 94103',
#   'street': '10TH ST',
#   'supervisor_district': '6.0',
#   'neighborhoods_sffind_boundaries': 'Showplace Square',
#   'analysis_neighborhood': 'South of Market',
#   'police_district': 'SOUTHERN',
#   'lat': '37.76967498185794',
#   'long': '-122.40876800408381',
#   'point': {'latitude': '37.76967498185794',
#    'longitude': '-122.40876800408381',
#    'human_address': '{"address": "", "city": "", "state": "", "zip": ""}'},
#   'point_geom': {'type': 'Point',
#    'coordinates': [-122.408768004, 37.769674982]},
#   'source': 'Mobile',
#   'data_as_of': '2026-06-08T01:00:00.000',
#   'data_loaded_at': '2026-06-08T03:13:41.000'},
#  {'service_request_id': '101004198641',
#   'requested_datetime': '2026-06-06T02:25:37.000',
#   'updated_datetime': '2026-06-06T02:25:47.000',
#   'status_description': 'Open',
#   'status_notes': 'open',
#   'agency_responsible': 'Noise Report',
#   'service_name': 'Noise',
#   'service_subtype': 'other_excessive_noise',
#   'address': '627 FILLMORE ST, SAN FRANCISCO, CA 94117',
#   'street': 'FILLMORE ST',
#   'supervisor_district': '5.0',
#   'neighborhoods_sffind_boundaries': 'Alamo Square',
#   'analysis_neighborhood': 'Hayes Valley',
#   'police_district': 'NORTHERN',
#   'lat': '37.775376311960684',
#   'long': '-122.43122688526931',
#   'point': {'latitude': '37.775376311960684',
#    'longitude': '-122.43122688526931',
#    'human_address': '{"address": "", "city": "", "state": "", "zip": ""}'},
#   'point_geom': {'type': 'Point',
#    'coordinates': [-122.431226885, 37.775376312]},
#   'source': 'Mobile',
#   'data_as_of': '2026-06-08T01:00:00.000',
#   'data_loaded_at': '2026-06-08T03:13:41.000'},
#  {'service_request_id': '101004198644',
#   'requested_datetime': '2026-06-06T02:27:22.000',
#   'updated_datetime': '2026-06-06T02:27:31.000',
#   'status_description': 'Open',
#   'status_notes': 'open',
#   'agency_responsible': 'Noise Report',
#   'service_name': 'Noise',
#   'service_subtype': 'other_excessive_noise',
#   'address': '145 FERN ST, SAN FRANCISCO, CA 94109',
#   'street': 'FERN ST',
#   'supervisor_district': '3.0',
#   'neighborhoods_sffind_boundaries': 'Lower Nob Hill',
#   'analysis_neighborhood': 'Nob Hill',
#   'police_district': 'NORTHERN',
#   'lat': '37.78803463173175',
#   'long': '-122.42086829707011',
#   'point': {'latitude': '37.78803463173175',
#    'longitude': '-122.42086829707011',
#    'human_address': '{"address": "", "city": "", "state": "", "zip": ""}'},
#   'point_geom': {'type': 'Point',
#    'coordinates': [-122.420868297, 37.788034632]},
#   'source': 'Mobile',
#   'data_as_of': '2026-06-08T01:00:00.000',
#   'data_loaded_at': '2026-06-08T03:13:41.000'},
#  {'service_request_id': '101004198646',
#   'requested_datetime': '2026-06-06T02:28:14.000',
#   'updated_datetime': '2026-06-06T02:28:27.000',
#   'status_description': 'Open',
#   'status_notes': 'open',
#   'agency_responsible': 'Noise Report',
#   'service_name': 'Noise',
#   'service_subtype': 'other_excessive_noise',
#   'address': '106 FERN ST, SAN FRANCISCO, CA 94109',
#   'street': 'FERN ST',
#   'supervisor_district': '3.0',
#   'neighborhoods_sffind_boundaries': 'Lower Nob Hill',
#   'analysis_neighborhood': 'Nob Hill',
#   'police_district': 'NORTHERN',
#   'lat': '37.788294214634526',
#   'long': '-122.42054276745662',
#   'point': {'latitude': '37.788294214634526',
#    'longitude': '-122.42054276745662',
#    'human_address': '{"address": "", "city": "", "state": "", "zip": ""}'},
#   'point_geom': {'type': 'Point',
#    'coordinates': [-122.420542767, 37.788294215]},
#   'source': 'Mobile',
#   'data_as_of': '2026-06-08T01:00:00.000',
#   'data_loaded_at': '2026-06-08T03:13:41.000'},
#  {'service_request_id': '101004198647',
#   'requested_datetime': '2026-06-06T02:30:54.000',
#   'updated_datetime': '2026-06-06T02:31:03.000',
#   'status_description': 'Open',
#   'status_notes': 'open',
#   'agency_responsible': 'Noise Report',
#   'service_name': 'Noise',
#   'service_subtype': 'other_excessive_noise',
#   'address': '2442 CLEMENT ST, SAN FRANCISCO, CA 94121',
#   'street': 'CLEMENT ST',
#   'supervisor_district': '1.0',
#   'neighborhoods_sffind_boundaries': 'Outer Richmond',
#   'analysis_neighborhood': 'Outer Richmond',
#   'police_district': 'RICHMOND',
#   'lat': '37.78218762099965',
#   'long': '-122.48562587399302',
#   'point': {'latitude': '37.78218762099965',
#    'longitude': '-122.48562587399302',
#    'human_address': '{"address": "", "city": "", "state": "", "zip": ""}'},
#   'point_geom': {'type': 'Point',
#    'coordinates': [-122.485625874, 37.782187621]},
#   'source': 'Mobile',
#   'data_as_of': '2026-06-08T01:00:00.000',
#   'data_loaded_at': '2026-06-08T03:13:41.000'},
#  {'service_request_id': '101004198648',
#   'requested_datetime': '2026-06-06T02:32:15.000',
#   'updated_datetime': '2026-06-06T02:32:24.000',
#   'status_description': 'Open',
#   'status_notes': 'open',
#   'agency_responsible': 'Noise Report',
#   'service_name': 'Noise',
#   'service_subtype': 'delivery_service_vehicle',
#   'address': '648 GOUGH ST, SAN FRANCISCO, CA 94102',
#   'street': 'GOUGH ST',
#   'supervisor_district': '5.0',
#   'neighborhoods_sffind_boundaries': 'Civic Center',
#   'analysis_neighborhood': 'Hayes Valley',
#   'police_district': 'NORTHERN',
#   'lat': '37.77937203668755',
#   'long': '-122.42340927314434',
#   'point': {'latitude': '37.77937203668755',
#    'longitude': '-122.42340927314434',
#    'human_address': '{"address": "", "city": "", "state": "", "zip": ""}'},
#   'point_geom': {'type': 'Point',
#    'coordinates': [-122.423409273, 37.779372037]},
#   'source': 'Mobile',
#   'data_as_of': '2026-06-08T01:00:00.000',
#   'data_loaded_at': '2026-06-08T03:13:41.000'},
#  {'service_request_id': '101004198393',
#   'requested_datetime': '2026-06-05T22:23:59.000',
#   'updated_datetime': '2026-06-06T02:36:06.000',
#   'status_description': 'Open',
#   'status_notes': 'open',
#   'agency_responsible': 'Port Authority',
#   'service_name': 'Street and Sidewalk Cleaning',
#   'service_subtype': 'garbage_and_debris',
#   'service_details': 'glass',
#   'address': '1044 BRIDGEVIEW, SAN FRANCISCO, CA 94158',
#   'street': 'BRIDGEVIEW',
#   'supervisor_district': '6.0',
#   'neighborhoods_sffind_boundaries': 'Mission Bay',
#   'analysis_neighborhood': 'Mission Bay',
#   'police_district': 'SOUTHERN',
#   'lat': '37.77574196',
#   'long': '-122.38820178',
#   'point': {'latitude': '37.77574196',
#    'longitude': '-122.38820178',
#    'human_address': '{"address": "", "city": "", "state": "", "zip": ""}'},
#   'point_geom': {'type': 'Point', 'coordinates': [-122.38820178, 37.77574196]},
#   'source': 'Web',
#   'media_url': {'url': 'https://sanfrancisco.form.us.empro.verintcloudservices.com/form/auto/download_attachments?caseid=101004198393&formref=LBP15569'},
#   'data_as_of': '2026-06-08T01:00:00.000',
#   'data_loaded_at': '2026-06-08T03:13:41.000'},
#  {'service_request_id': '101004198651',
#   'requested_datetime': '2026-06-06T02:36:30.000',
#   'updated_datetime': '2026-06-06T02:36:36.000',
#   'status_description': 'Open',
#   'status_notes': 'open',
#   'agency_responsible': 'Noise Report',
#   'service_name': 'Noise',
#   'service_subtype': 'rv_oversize_vehicle',
#   'address': '630 GOUGH ST, SAN FRANCISCO, CA 94102',
#   'street': 'GOUGH ST',
#   'supervisor_district': '5.0',
#   'neighborhoods_sffind_boundaries': 'Civic Center',
#   'analysis_neighborhood': 'Hayes Valley',
#   'police_district': 'NORTHERN',
#   'lat': '37.77949572121643',
#   'long': '-122.42342328436993',
#   'point': {'latitude': '37.77949572121643',
#    'longitude': '-122.42342328436993',
#    'human_address': '{"address": "", "city": "", "state": "", "zip": ""}'},
#   'point_geom': {'type': 'Point',
#    'coordinates': [-122.423423284, 37.779495721]},
#   'source': 'Mobile',
#   'data_as_of': '2026-06-08T01:00:00.000',
#   'data_loaded_at': '2026-06-08T03:13:41.000'},
#  {'service_request_id': '101004198660',
#   'requested_datetime': '2026-06-06T02:43:59.000',
#   'updated_datetime': '2026-06-06T02:44:41.000',
#   'status_description': 'Open',
#   'status_notes': 'open',
#   'agency_responsible': 'Board of Supervisors - Clerk of the Board',
#   'service_name': 'General Request',
#   'service_subtype': 'board_of_supervisors',
#   'service_details': 'board_of_supervisors complaint',
#   'address': 'INTERSECTION I-80 W ON RAMP, I-80 WESTBOUND, SAN FRANCISCO, CA 94107',
#   'street': 'I-80 W ON RAMP',
#   'supervisor_district': '6.0',
#   'neighborhoods_sffind_boundaries': 'South of Market',
#   'analysis_neighborhood': 'South of Market',
#   'police_district': 'SOUTHERN',
#   'lat': '37.7779261301',
#   'long': '-122.4021755399',
#   'point': {'latitude': '37.7779261301',
#    'longitude': '-122.4021755399',
#    'human_address': '{"address": "", "city": "", "state": "", "zip": ""}'},
#   'point_geom': {'type': 'Point', 'coordinates': [-122.40217554, 37.77792613]},
#   'source': 'Web',
#   'media_url': {'url': 'https://sanfrancisco.form.us.empro.verintcloudservices.com/form/auto/download_attachments?caseid=101004198660&formref=QXO8P1X2'},
#   'data_as_of': '2026-06-08T01:00:00.000',
#   'data_loaded_at': '2026-06-08T03:13:41.000'},
#  {'service_request_id': '101004198643',
#   'requested_datetime': '2026-06-06T02:26:54.000',
#   'closed_date': '2026-06-06T04:23:51.000',
#   'updated_datetime': '2026-06-06T03:23:54.000',
#   'status_description': 'Closed',
#   'status_notes': 'Case is a Duplicate - This issue has already been reported through an earlier request.',
#   'agency_responsible': 'MTA - Parking Enforcement Dispatch',
#   'service_name': 'Parking Enforcement',
#   'service_subtype': 'other_illegal_parking',
#   'address': '140 FERN ST, SAN FRANCISCO, CA 94109',
#   'street': 'FERN ST',
#   'supervisor_district': '3.0',
#   'neighborhoods_sffind_boundaries': 'Lower Nob Hill',
#   'analysis_neighborhood': 'Nob Hill',
#   'police_district': 'NORTHERN',
#   'lat': '37.78821415202734',
#   'long': '-122.42095658238102',
#   'point': {'latitude': '37.78821415202734',
#    'longitude': '-122.42095658238102',
#    'human_address': '{"address": "", "city": "", "state": "", "zip": ""}'},
#   'point_geom': {'type': 'Point',
#    'coordinates': [-122.420956582, 37.788214152]},
#   'source': 'Mobile',
#   'data_as_of': '2026-06-08T01:00:00.000',
#   'data_loaded_at': '2026-06-08T03:13:41.000'},
#  {'service_request_id': '101004198674',
#   'requested_datetime': '2026-06-06T03:25:43.000',
#   'updated_datetime': '2026-06-06T03:25:43.000',
#   'status_description': 'Open',
#   'status_notes': 'open',
#   'agency_responsible': 'Noise Report',
#   'service_name': 'Noise',
#   'service_subtype': 'other_excessive_noise',
#   'address': '154 ARGUELLO BLVD, SAN FRANCISCO, CA 94118',
#   'street': 'ARGUELLO BLVD',
#   'supervisor_district': '2.0',
#   'neighborhoods_sffind_boundaries': 'Presidio Heights',
#   'analysis_neighborhood': 'Presidio Heights',
#   'police_district': 'RICHMOND',
#   'lat': '37.78735123',
#   'long': '-122.45909983',
#   'point': {'latitude': '37.78735123',
#    'longitude': '-122.45909983',
#    'human_address': '{"address": "", "city": "", "state": "", "zip": ""}'},
#   'point_geom': {'type': 'Point', 'coordinates': [-122.45909983, 37.78735123]},
#   'source': 'Phone',
#   'data_as_of': '2026-06-08T01:00:00.000',
#   'data_loaded_at': '2026-06-08T03:13:41.000'},
#  {'service_request_id': '101004194021',
#   'requested_datetime': '2026-06-05T10:06:00.000',
#   'updated_datetime': '2026-06-06T03:35:35.000',
#   'status_description': 'Open',
#   'status_notes': 'open',
#   'agency_responsible': 'PW - Street and Environmental Services',
#   'service_name': 'Graffiti Private',
#   'service_subtype': 'not_offensive',
#   'service_details': 'building_commercial',
#   'address': '178 13TH ST, SAN FRANCISCO, CA 94103',
#   'street': '13TH ST',
#   'supervisor_district': '6.0',
#   'neighborhoods_sffind_boundaries': 'South of Market',
#   'analysis_neighborhood': 'Mission',
#   'police_district': 'MISSION',
#   'lat': '37.76984371',
#   'long': '-122.41721072',
#   'point': {'latitude': '37.76984371',
#    'longitude': '-122.41721072',
#    'human_address': '{"address": "", "city": "", "state": "", "zip": ""}'},
#   'point_geom': {'type': 'Point', 'coordinates': [-122.41721072, 37.76984371]},
#   'source': 'Web',
#   'media_url': {'url': 'https://sanfrancisco.form.us.empro.verintcloudservices.com/form/auto/download_attachments?caseid=101004194021&formref=H054CAW0'},
#   'data_as_of': '2026-06-08T01:00:00.000',
#   'data_loaded_at': '2026-06-08T03:13:41.000'},
#  {'service_request_id': '101004198689',
#   'requested_datetime': '2026-06-06T04:06:21.000',
#   'updated_datetime': '2026-06-06T04:06:27.000',
#   'status_description': 'Open',
#   'status_notes': 'open',
#   'agency_responsible': 'Noise Report',
#   'service_name': 'Noise',
#   'service_subtype': 'other_excessive_noise',
#   'address': '520 STEVENSON ST, SAN FRANCISCO, CA 94103',
#   'street': 'STEVENSON ST',
#   'supervisor_district': '6.0',
#   'neighborhoods_sffind_boundaries': 'South of Market',
#   'analysis_neighborhood': 'South of Market',
#   'police_district': 'TENDERLOIN',
#   'lat': '37.78139527401052',
#   'long': '-122.41029124706984',
#   'point': {'latitude': '37.78139527401052',
#    'longitude': '-122.41029124706984',
#    'human_address': '{"address": "", "city": "", "state": "", "zip": ""}'},
#   'point_geom': {'type': 'Point',
#    'coordinates': [-122.410291247, 37.781395274]},
#   'source': 'Mobile',
#   'data_as_of': '2026-06-08T01:00:00.000',
#   'data_loaded_at': '2026-06-08T03:13:41.000'},
#  {'service_request_id': '101004198598',
#   'requested_datetime': '2026-06-06T01:05:17.000',
#   'closed_date': '2026-06-06T05:07:38.000',
#   'updated_datetime': '2026-06-06T04:07:42.000',
#   'status_description': 'Closed',
#   'status_notes': 'Case Resolved - Officer responded to request under CAD # 261570126.  Issue reported could not be validated.',
#   'agency_responsible': 'MTA - Parking Enforcement Dispatch',
#   'service_name': 'Parking Enforcement',
#   'service_subtype': 'parking_on_sidewalk',
#   'address': '41 OLYMPIA WAY, SAN FRANCISCO, CA 94131',
#   'street': 'OLYMPIA WAY',
#   'supervisor_district': '7.0',
#   'neighborhoods_sffind_boundaries': 'Midtown Terrace',
#   'analysis_neighborhood': 'Twin Peaks',
#   'police_district': 'PARK',
#   'lat': '37.75107574346905',
#   'long': '-122.45287709210069',
#   'point': {'latitude': '37.75107574346905',
#    'longitude': '-122.45287709210069',
#    'human_address': '{"address": "", "city": "", "state": "", "zip": ""}'},
#   'point_geom': {'type': 'Point',
#    'coordinates': [-122.452877092, 37.751075743]},
#   'source': 'Mobile',
#   'media_url': {'url': 'https://spot-sf-res.cloudinary.com/image/upload/v1780733112/san-francisco/production/tzuetwaiyfgcmuzd5uox.jpg'},
#   'data_as_of': '2026-06-08T01:00:00.000',
#   'data_loaded_at': '2026-06-08T03:13:41.000'},
#  {'service_request_id': '101004193086',
#   'requested_datetime': '2026-06-05T08:19:53.000',
#   'updated_datetime': '2026-06-06T04:40:05.000',
#   'status_description': 'Open',
#   'status_notes': 'accepted',
#   'agency_responsible': 'MTA - Parking Meter Shop',
#   'service_name': 'Graffiti Public',
#   'service_subtype': 'not_offensive',
#   'service_details': 'pole',
#   'address': '1957 MISSION ST, SAN FRANCISCO, CA 94103',
#   'street': 'MISSION ST',
#   'supervisor_district': '9.0',
#   'neighborhoods_sffind_boundaries': 'Mission',
#   'analysis_neighborhood': 'Mission',
#   'police_district': 'MISSION',
#   'lat': '37.76576823',
#   'long': '-122.41963324',
#   'point': {'latitude': '37.76576823',
#    'longitude': '-122.41963324',
#    'human_address': '{"address": "", "city": "", "state": "", "zip": ""}'},
#   'point_geom': {'type': 'Point', 'coordinates': [-122.41963324, 37.76576823]},
#   'source': 'Web',
#   'media_url': {'url': 'https://sanfrancisco.form.us.empro.verintcloudservices.com/form/auto/download_attachments?caseid=101004193086&formref=SHS4HTV5'},
#   'data_as_of': '2026-06-08T01:00:00.000',
#   'data_loaded_at': '2026-06-08T03:13:41.000'},
#  {'service_request_id': '101004196379',
#   'requested_datetime': '2026-06-05T15:06:29.000',
#   'updated_datetime': '2026-06-06T04:40:10.000',
#   'status_description': 'Open',
#   'status_notes': 'accepted',
#   'agency_responsible': 'MTA - Parking Meter Shop',
#   'service_name': 'MTA Parking Traffic Signs Normal Priority',
#   'service_subtype': 'other',
#   'service_details': 'other other',
#   'address': '815 EDDY ST, SAN FRANCISCO, CA 94109',
#   'street': 'EDDY ST',
#   'supervisor_district': '2.0',
#   'neighborhoods_sffind_boundaries': 'Cathedral Hill',
#   'analysis_neighborhood': 'Western Addition',
#   'police_district': 'NORTHERN',
#   'lat': '37.782851627251',
#   'long': '-122.42106165736914',
#   'point': {'latitude': '37.782851627251',
#    'longitude': '-122.42106165736914',
#    'human_address': '{"address": "", "city": "", "state": "", "zip": ""}'},
#   'point_geom': {'type': 'Point',
#    'coordinates': [-122.421061657, 37.782851627]},
#   'source': 'Mobile',
#   'media_url': {'url': 'https://spot-sf-res.cloudinary.com/image/upload/v1780697187/san-francisco/production/bsqjkkvfcymn1s55cgjy.jpg'},
#   'data_as_of': '2026-06-08T01:00:00.000',
#   'data_loaded_at': '2026-06-08T03:13:41.000'},
#  {'service_request_id': '101004195368',
#   'requested_datetime': '2026-06-05T12:48:24.000',
#   'updated_datetime': '2026-06-06T04:40:14.000',
#   'status_description': 'Open',
#   'status_notes': 'accepted',
#   'agency_responsible': 'MTA - Parking Meter Shop',
#   'service_name': 'Damage Property',
#   'service_subtype': 'parking_meter',
#   'address': 'INTERSECTION CASTRO ST, 18TH ST, SAN FRANCISCO, CA 94114',
#   'street': 'CASTRO ST',
#   'supervisor_district': '8.0',
#   'neighborhoods_sffind_boundaries': 'Castro',
#   'analysis_neighborhood': 'Castro/Upper Market',
#   'police_district': 'MISSION',
#   'lat': '37.7608889247',
#   'long': '-122.4350008178',
#   'point': {'latitude': '37.7608889247',
#    'longitude': '-122.4350008178',
#    'human_address': '{"address": "", "city": "", "state": "", "zip": ""}'},
#   'point_geom': {'type': 'Point',
#    'coordinates': [-122.435000818, 37.760888925]},
#   'source': 'Phone',
#   'data_as_of': '2026-06-08T01:00:00.000',
#   'data_loaded_at': '2026-06-08T03:13:41.000'},
#  {'service_request_id': '101004195811',
#   'requested_datetime': '2026-06-05T13:48:35.000',
#   'updated_datetime': '2026-06-06T04:40:19.000',
#   'status_description': 'Open',
#   'status_notes': 'accepted',
#   'agency_responsible': 'MTA - Parking Meter Shop',
#   'service_name': 'Damage Property',
#   'service_subtype': 'parking_meter',
#   'address': 'INTERSECTION NORIEGA ST, 31ST AVE, SAN FRANCISCO, CA 94122',
#   'street': 'NORIEGA ST',
#   'supervisor_district': '4.0',
#   'neighborhoods_sffind_boundaries': 'Outer Sunset',
#   'analysis_neighborhood': 'Sunset/Parkside',
#   'police_district': 'TARAVAL',
#   'lat': '37.7536742261',
#   'long': '-122.4893235435',
#   'point': {'latitude': '37.7536742261',
#    'longitude': '-122.4893235435',
#    'human_address': '{"address": "", "city": "", "state": "", "zip": ""}'},
#   'point_geom': {'type': 'Point',
#    'coordinates': [-122.489323544, 37.753674226]},
#   'source': 'Phone',
#   'data_as_of': '2026-06-08T01:00:00.000',
#   'data_loaded_at': '2026-06-08T03:13:41.000'},
#  {'service_request_id': '101004197414',
#   'requested_datetime': '2026-06-05T17:49:53.000',
#   'updated_datetime': '2026-06-06T04:40:23.000',
#   'status_description': 'Open',
#   'status_notes': 'accepted',
#   'agency_responsible': 'MTA - Parking Meter Shop',
#   'service_name': 'Graffiti Public',
#   'service_subtype': 'not_offensive',
#   'service_details': 'parking_meter',
#   'address': '5 BLUXOME ST, SAN FRANCISCO, CA 94107',
#   'street': 'BLUXOME ST',
#   'supervisor_district': '6.0',
#   'neighborhoods_sffind_boundaries': 'South of Market',
#   'analysis_neighborhood': 'South of Market',
#   'police_district': 'SOUTHERN',
#   'lat': '37.77754907',
#   'long': '-122.39585951',
#   'point': {'latitude': '37.77754907',
#    'longitude': '-122.39585951',
#    'human_address': '{"address": "", "city": "", "state": "", "zip": ""}'},
#   'point_geom': {'type': 'Point', 'coordinates': [-122.39585951, 37.77754907]},
#   'source': 'Web',
#   'media_url': {'url': 'https://sanfrancisco.form.us.empro.verintcloudservices.com/form/auto/download_attachments?caseid=101004197414&formref=5VU38660'},
#   'data_as_of': '2026-06-08T01:00:00.000',
#   'data_loaded_at': '2026-06-08T03:13:41.000'},
#  {'service_request_id': '101004195395',
#   'requested_datetime': '2026-06-05T12:53:27.000',
#   'updated_datetime': '2026-06-06T04:40:28.000',
#   'status_description': 'Open',
#   'status_notes': 'accepted',
#   'agency_responsible': 'MTA - Parking Meter Shop',
#   'service_name': 'Damage Property',
#   'service_subtype': 'parking_meter',
#   'address': '300 FULTON ST, SAN FRANCISCO, CA 94102',
#   'street': 'FULTON ST',
#   'supervisor_district': '5.0',
#   'neighborhoods_sffind_boundaries': 'Civic Center',
#   'analysis_neighborhood': 'Hayes Valley',
#   'police_district': 'NORTHERN',
#   'lat': '37.7790048',
#   'long': '-122.42176961',
#   'point': {'latitude': '37.7790048',
#    'longitude': '-122.42176961',
#    'human_address': '{"address": "", "city": "", "state": "", "zip": ""}'},
#   'point_geom': {'type': 'Point', 'coordinates': [-122.42176961, 37.7790048]},
#   'source': 'Phone',
#   'data_as_of': '2026-06-08T01:00:00.000',
#   'data_loaded_at': '2026-06-08T03:13:41.000'},
#  {'service_request_id': '101004193798',
#   'requested_datetime': '2026-06-05T09:38:06.000',
#   'updated_datetime': '2026-06-06T04:40:32.000',
#   'status_description': 'Open',
#   'status_notes': 'accepted',
#   'agency_responsible': 'MTA - Parking Meter Shop',
#   'service_name': 'Damage Property',
#   'service_subtype': 'parking_meter',
#   'address': '541 ELLIS ST, SAN FRANCISCO, CA 94109',
#   'street': 'ELLIS ST',
#   'supervisor_district': '5.0',
#   'neighborhoods_sffind_boundaries': 'Tenderloin',
#   'analysis_neighborhood': 'Tenderloin',
#   'police_district': 'TENDERLOIN',
#   'lat': '37.78443793',
#   'long': '-122.41516778',
#   'point': {'latitude': '37.78443793',
#    'longitude': '-122.41516778',
#    'human_address': '{"address": "", "city": "", "state": "", "zip": ""}'},
#   'point_geom': {'type': 'Point', 'coordinates': [-122.41516778, 37.78443793]},
#   'source': 'Phone',
#   'data_as_of': '2026-06-08T01:00:00.000',
#   'data_loaded_at': '2026-06-08T03:13:41.000'},
#  {'service_request_id': '101004195497',
#   'requested_datetime': '2026-06-05T13:05:15.000',
#   'updated_datetime': '2026-06-06T04:40:36.000',
#   'status_description': 'Open',
#   'status_notes': 'accepted',
#   'agency_responsible': 'MTA - Parking Meter Shop',
#   'service_name': 'Damage Property',
#   'service_subtype': 'parking_meter',
#   'address': 'INTERSECTION HAIGHT ST, CENTRAL AVE, SAN FRANCISCO, CA 94117',
#   'street': 'HAIGHT ST',
#   'supervisor_district': '5.0',
#   'neighborhoods_sffind_boundaries': 'Haight Ashbury',
#   'analysis_neighborhood': 'Haight Ashbury',
#   'police_district': 'PARK',
#   'lat': '37.7704262723',
#   'long': '-122.4436492477',
#   'point': {'latitude': '37.7704262723',
#    'longitude': '-122.4436492477',
#    'human_address': '{"address": "", "city": "", "state": "", "zip": ""}'},
#   'point_geom': {'type': 'Point',
#    'coordinates': [-122.443649248, 37.770426272]},
#   'source': 'Phone',
#   'data_as_of': '2026-06-08T01:00:00.000',
#   'data_loaded_at': '2026-06-08T03:13:41.000'},
#  {'service_request_id': '101004193511',
#   'requested_datetime': '2026-06-05T09:07:47.000',
#   'updated_datetime': '2026-06-06T04:40:41.000',
#   'status_description': 'Open',
#   'status_notes': 'accepted',
#   'agency_responsible': 'MTA - Parking Meter Shop',
#   'service_name': 'Damage Property',
#   'service_subtype': 'parking_meter',
#   'address': 'INTERSECTION THE EMBARCADERO, BRYANT ST, SAN FRANCISCO, CA 94105',
#   'street': 'THE EMBARCADERO',
#   'supervisor_district': '6.0',
#   'neighborhoods_sffind_boundaries': 'Rincon Hill',
#   'analysis_neighborhood': 'Financial District/South Beach',
#   'police_district': 'SOUTHERN',
#   'lat': '37.7870972248',
#   'long': '-122.387794889',
#   'point': {'latitude': '37.7870972248',
#    'longitude': '-122.387794889',
#    'human_address': '{"address": "", "city": "", "state": "", "zip": ""}'},
#   'point_geom': {'type': 'Point',
#    'coordinates': [-122.387794889, 37.787097225]},
#   'source': 'Phone',
#   'data_as_of': '2026-06-08T01:00:00.000',
#   'data_loaded_at': '2026-06-08T03:13:41.000'},
#  {'service_request_id': '101004194888',
#   'requested_datetime': '2026-06-05T11:48:12.000',
#   'updated_datetime': '2026-06-06T04:40:45.000',
#   'status_description': 'Open',
#   'status_notes': 'accepted',
#   'agency_responsible': 'MTA - Parking Meter Shop',
#   'service_name': 'Damage Property',
#   'service_subtype': 'parking_meter',
#   'address': 'INTERSECTION MISSION ST, ALLISON ST, SAN FRANCISCO, CA 94112',
#   'street': 'MISSION ST',
#   'supervisor_district': '11.0',
#   'neighborhoods_sffind_boundaries': 'Cayuga',
#   'analysis_neighborhood': 'Excelsior',
#   'police_district': 'INGLESIDE',
#   'lat': '37.7146605589',
#   'long': '-122.4425648964',
#   'point': {'latitude': '37.7146605589',
#    'longitude': '-122.4425648964',
#    'human_address': '{"address": "", "city": "", "state": "", "zip": ""}'},
#   'point_geom': {'type': 'Point',
#    'coordinates': [-122.442564896, 37.714660559]},
#   'source': 'Phone',
#   'data_as_of': '2026-06-08T01:00:00.000',
#   'data_loaded_at': '2026-06-08T03:13:41.000'},
#  {'service_request_id': '101004198498',
#   'requested_datetime': '2026-06-05T23:15:45.000',
#   'closed_date': '2026-06-06T05:47:02.000',
#   'updated_datetime': '2026-06-06T04:47:07.000',
#   'status_description': 'Closed',
#   'status_notes': 'Case Resolved - Officer responded to request under CAD # 261563572. Individual(s) not found at location provided.',
#   'agency_responsible': 'MTA - Parking Enforcement Dispatch',
#   'service_name': 'Parking Enforcement',
#   'service_subtype': 'other_illegal_parking',
#   'address': '530 NATOMA ST, SAN FRANCISCO, CA 94103',
#   'street': 'NATOMA ST',
#   'supervisor_district': '6.0',
#   'neighborhoods_sffind_boundaries': 'South of Market',
#   'analysis_neighborhood': 'South of Market',
#   'police_district': 'SOUTHERN',
#   'lat': '37.77968788381686',
#   'long': '-122.408437751488',
#   'point': {'latitude': '37.77968788381686',
#    'longitude': '-122.408437751488',
#    'human_address': '{"address": "", "city": "", "state": "", "zip": ""}'},
#   'point_geom': {'type': 'Point',
#    'coordinates': [-122.408437751, 37.779687884]},
#   'source': 'Mobile',
#   'data_as_of': '2026-06-08T01:00:00.000',
#   'data_loaded_at': '2026-06-08T03:13:41.000'},
#  {'service_request_id': '101004198645',
#   'requested_datetime': '2026-06-06T02:27:38.000',
#   'closed_date': '2026-06-06T05:52:12.000',
#   'updated_datetime': '2026-06-06T04:52:16.000',
#   'status_description': 'Closed',
#   'status_notes': 'Case Resolved - Officer responded to request under CAD # 261570276. Unable to Locate.',
#   'agency_responsible': 'MTA - Parking Enforcement Dispatch',
#   'service_name': 'Parking Enforcement',
#   'service_subtype': 'parking_on_sidewalk',
#   'address': '1101 4TH ST, SAN FRANCISCO, CA 94158',
#   'street': '4TH ST',
#   'supervisor_district': '6.0',
#   'neighborhoods_sffind_boundaries': 'Mission Bay',
#   'analysis_neighborhood': 'Mission Bay',
#   'police_district': 'SOUTHERN',
#   'lat': '37.77431595',
#   'long': '-122.39155881',
#   'point': {'latitude': '37.77431595',
#    'longitude': '-122.39155881',
#    'human_address': '{"address": "", "city": "", "state": "", "zip": ""}'},
#   'point_geom': {'type': 'Point', 'coordinates': [-122.39155881, 37.77431595]},
#   'source': 'Phone',
#   'data_as_of': '2026-06-08T01:00:00.000',
#   'data_loaded_at': '2026-06-08T03:13:41.000'},
#  {'service_request_id': '101004198704',
#   'requested_datetime': '2026-06-06T05:07:11.000',
#   'updated_datetime': '2026-06-06T05:07:11.000',
#   'status_description': 'Open',
#   'status_notes': 'open',
#   'agency_responsible': 'Noise Report',
#   'service_name': 'Noise',
# ...
#   'source': 'Web',
#   'data_as_of': '2026-06-08T01:00:00.000',
#   'data_loaded_at': '2026-06-08T03:13:41.000'},
#  {'service_request_id': '101004199393',
#   'requested_datetime': '2026-06-06T09:05:56.000',
#   'updated_datetime': '2026-06-06T11:17:25.000',
#   'status_description': 'Open',
#   'status_notes': 'open',
#   'agency_responsible': 'RPD - GGP',
#   'service_name': 'RPD General',
#   'service_subtype': 'structural_maintenance',
#   'service_details': 'graffiti',
#   'address': '1700 OAK ST, SAN FRANCISCO, CA 94117',
#   'street': 'OAK ST',
#   'supervisor_district': '5.0',
#   'neighborhoods_sffind_boundaries': 'Haight Ashbury',
#   'analysis_neighborhood': 'Golden Gate Park',
#   'police_district': 'PARK',
#   'lat': '37.77194168',
#   'long': '-122.44746506',
#   'point': {'latitude': '37.77194168',
#    'longitude': '-122.44746506',
#    'human_address': '{"address": "", "city": "", "state": "", "zip": ""}'},
#   'point_geom': {'type': 'Point', 'coordinates': [-122.44746506, 37.77194168]},
#   'source': 'Web',
#   'media_url': {'url': 'https://sanfrancisco.form.us.empro.verintcloudservices.com/form/auto/download_attachments?caseid=101004199393&formref=YSE7WNR6'},
#   'data_as_of': '2026-06-08T01:00:00.000',
#   'data_loaded_at': '2026-06-08T03:13:41.000'},
#  {'service_request_id': '101004199929',
#   'requested_datetime': '2026-06-06T10:34:51.000',
#   'closed_date': '2026-06-06T12:17:30.000',
#   'updated_datetime': '2026-06-06T11:17:33.000',
#   'status_description': 'Closed',
#   'status_notes': 'Case Resolved - Officer responded to request under CAD # 261571160. Unable to Locate.',
#   'agency_responsible': 'MTA - Parking Enforcement Dispatch',
#   'service_name': 'Parking Enforcement',
#   'service_subtype': 'blocking_driveway_cite_tow',
#   'address': '176 28TH ST, SAN FRANCISCO, CA 94131',
#   'street': '28TH ST',
#   'supervisor_district': '8.0',
#   'neighborhoods_sffind_boundaries': 'Noe Valley',
#   'analysis_neighborhood': 'Noe Valley',
#   'police_district': 'INGLESIDE',
#   'lat': '37.74543546',
#   'long': '-122.42620995',
#   'point': {'latitude': '37.74543546',
#    'longitude': '-122.42620995',
#    'human_address': '{"address": "", "city": "", "state": "", "zip": ""}'},
#   'point_geom': {'type': 'Point', 'coordinates': [-122.42620995, 37.74543546]},
#   'source': 'Phone',
#   'data_as_of': '2026-06-08T01:00:00.000',
#   'data_loaded_at': '2026-06-08T03:13:41.000'},
#  {'service_request_id': '101004199549',
#   'requested_datetime': '2026-06-06T09:30:34.000',
#   'closed_date': '2026-06-06T12:11:58.000',
#   'updated_datetime': '2026-06-06T11:17:34.000',
#   'status_description': 'Closed',
#   'status_notes': 'Case Resolved - No Work Needed',
#   'agency_responsible': 'PW - Street and Environmental Services',
#   'service_name': 'Street and Sidewalk Cleaning',
#   'service_subtype': 'garbage_and_debris',
#   'service_details': 'other_loose_garbage_debris_yard_waste',
#   'address': '333 FILLMORE ST, SAN FRANCISCO, CA 94117',
#   'street': 'FILLMORE ST',
#   'supervisor_district': '5.0',
#   'neighborhoods_sffind_boundaries': 'Lower Haight',
#   'analysis_neighborhood': 'Hayes Valley',
#   'police_district': 'NORTHERN',
#   'lat': '37.77253839890499',
#   'long': '-122.43065942817671',
#   'point': {'latitude': '37.77253839890499',
#    'longitude': '-122.43065942817671',
#    'human_address': '{"address": "", "city": "", "state": "", "zip": ""}'},
#   'point_geom': {'type': 'Point',
#    'coordinates': [-122.430659428, 37.772538399]},
#   'source': 'Mobile',
#   'media_url': {'url': 'https://spot-sf-res.cloudinary.com/image/upload/v1780763433/san-francisco/production/t0d4fgwtshjr23twdfyb.jpg'},
#   'data_as_of': '2026-06-08T01:00:00.000',
#   'data_loaded_at': '2026-06-08T03:13:41.000'},
#  {'service_request_id': '101004199223',
#   'requested_datetime': '2026-06-06T08:28:04.000',
#   'closed_date': '2026-06-06T12:13:45.000',
#   'updated_datetime': '2026-06-06T11:17:37.000',
#   'status_description': 'Closed',
#   'status_notes': 'Case Resolved - No Work Needed',
#   'agency_responsible': 'PW - Street and Environmental Services',
#   'service_name': 'Street and Sidewalk Cleaning',
#   'service_subtype': 'garbage_and_debris',
#   'service_details': 'human_waste_or_urine',
#   'address': '79 6TH ST, SAN FRANCISCO, CA 94103',
#   'street': '6TH ST',
#   'supervisor_district': '6.0',
#   'neighborhoods_sffind_boundaries': 'South of Market',
#   'analysis_neighborhood': 'South of Market',
#   'police_district': 'TENDERLOIN',
#   'lat': '37.78120719356966',
#   'long': '-122.40903878934871',
#   'point': {'latitude': '37.78120719356966',
#    'longitude': '-122.40903878934871',
#    'human_address': '{"address": "", "city": "", "state": "", "zip": ""}'},
#   'point_geom': {'type': 'Point',
#    'coordinates': [-122.409038789, 37.781207194]},
#   'source': 'Mobile',
#   'media_url': {'url': 'https://spot-sf-res.cloudinary.com/image/upload/v1780759682/san-francisco/production/rmhaw1e7jpnbomgqbdcu.jpg'},
#   'data_as_of': '2026-06-08T01:00:00.000',
#   'data_loaded_at': '2026-06-08T03:13:41.000'},
#  {'service_request_id': '101003805847',
#   'requested_datetime': '2026-04-03T21:38:15.000',
#   'closed_date': '2026-06-05T11:13:19.000',
#   'updated_datetime': '2026-06-06T11:17:41.000',
#   'status_description': 'Closed',
#   'status_notes': 'Case Resolved',
#   'agency_responsible': 'PW - Street and Environmental Services',
#   'service_name': 'Litter Receptacle Maintenance',
#   'service_subtype': 'toters_left_out_24x7',
#   'address': '619 41ST AVE, SAN FRANCISCO, CA 94121',
#   'street': '41ST AVE',
#   'supervisor_district': '1.0',
#   'neighborhoods_sffind_boundaries': 'Outer Richmond',
#   'analysis_neighborhood': 'Outer Richmond',
#   'police_district': 'RICHMOND',
#   'lat': '37.77689937082127',
#   'long': '-122.50189002603292',
#   'point': {'latitude': '37.77689937082127',
#    'longitude': '-122.50189002603292',
#    'human_address': '{"address": "", "city": "", "state": "", "zip": ""}'},
#   'point_geom': {'type': 'Point',
#    'coordinates': [-122.501890026, 37.776899371]},
#   'source': 'Mobile',
#   'media_url': {'url': 'https://spot-sf-res.cloudinary.com/image/upload/v1775277494/san-francisco/production/n1hp93ybawln8xaedyhj.jpg'},
#   'data_as_of': '2026-06-08T01:00:00.000',
#   'data_loaded_at': '2026-06-08T03:13:41.000'},
#  {'service_request_id': '101004193976',
#   'requested_datetime': '2026-06-05T10:00:47.000',
#   'closed_date': '2026-06-06T12:12:51.000',
#   'updated_datetime': '2026-06-06T11:17:41.000',
#   'status_description': 'Closed',
#   'status_notes': 'Case Resolved - Resolved',
#   'agency_responsible': 'PW - Street and Environmental Services',
#   'service_name': 'Street and Sidewalk Cleaning',
#   'service_subtype': 'garbage_and_debris',
#   'service_details': 'other_loose_garbage_debris_yard_waste',
#   'address': '716 SOUTH VAN NESS AVE, SAN FRANCISCO, CA 94110',
#   'street': 'SOUTH VAN NESS AVE',
#   'supervisor_district': '9.0',
#   'neighborhoods_sffind_boundaries': 'Mission',
#   'analysis_neighborhood': 'Mission',
#   'police_district': 'MISSION',
#   'lat': '37.76162095856851',
#   'long': '-122.41727303540415',
#   'point': {'latitude': '37.76162095856851',
#    'longitude': '-122.41727303540415',
#    'human_address': '{"address": "", "city": "", "state": "", "zip": ""}'},
#   'point_geom': {'type': 'Point',
#    'coordinates': [-122.417273035, 37.761620959]},
#   'source': 'Mobile',
#   'media_url': {'url': 'https://spot-sf-res.cloudinary.com/image/upload/v1780678846/san-francisco/production/rvtfdfjw8k7yoe3d9gno.jpg'},
#   'data_as_of': '2026-06-08T01:00:00.000',
#   'data_loaded_at': '2026-06-08T03:13:41.000'},
#  {'service_request_id': '101003891037',
#   'requested_datetime': '2026-04-17T16:48:17.000',
#   'closed_date': '2026-06-05T11:18:14.000',
#   'updated_datetime': '2026-06-06T11:17:42.000',
#   'status_description': 'Closed',
#   'status_notes': 'Case Resolved - addressed overgrowth on previously issued enforcement',
#   'agency_responsible': 'PW - Street and Environmental Services',
#   'service_name': 'General Request',
#   'service_subtype': 'public_works',
#   'service_details': 'buf request_for_service',
#   'address': '162 ARCH ST, SAN FRANCISCO, CA 94132',
#   'street': 'ARCH ST',
#   'supervisor_district': '11.0',
#   'neighborhoods_sffind_boundaries': 'Merced Heights',
#   'analysis_neighborhood': 'Oceanview/Merced/Ingleside',
#   'police_district': 'TARAVAL',
#   'lat': '37.71364055',
#   'long': '-122.46694525',
#   'point': {'latitude': '37.71364055',
#    'longitude': '-122.46694525',
#    'human_address': '{"address": "", "city": "", "state": "", "zip": ""}'},
#   'point_geom': {'type': 'Point', 'coordinates': [-122.46694525, 37.71364055]},
#   'source': 'Phone',
#   'data_as_of': '2026-06-08T01:00:00.000',
#   'data_loaded_at': '2026-06-08T03:13:41.000'},
#  {'service_request_id': '101003827886',
#   'requested_datetime': '2026-04-07T16:54:18.000',
#   'closed_date': '2026-06-05T11:22:31.000',
#   'updated_datetime': '2026-06-06T11:17:44.000',
#   'status_description': 'Closed',
#   'status_notes': 'Case Resolved - Various inspections completed and problem unfounded. Please re-report if in error.',
#   'agency_responsible': 'PW - Street and Environmental Services',
#   'service_name': 'Litter Receptacle Maintenance',
#   'service_subtype': 'toters_left_out_24x7',
#   'address': '496 38TH AVE, SAN FRANCISCO, CA 94121',
#   'street': '38TH AVE',
#   'supervisor_district': '1.0',
#   'neighborhoods_sffind_boundaries': 'Outer Richmond',
#   'analysis_neighborhood': 'Outer Richmond',
#   'police_district': 'RICHMOND',
#   'lat': '37.77961329624957',
#   'long': '-122.49855655777846',
#   'point': {'latitude': '37.77961329624957',
#    'longitude': '-122.49855655777846',
#    'human_address': '{"address": "", "city": "", "state": "", "zip": ""}'},
#   'point_geom': {'type': 'Point',
#    'coordinates': [-122.498556558, 37.779613296]},
#   'source': 'Mobile',
#   'media_url': {'url': 'https://spot-sf-res.cloudinary.com/image/upload/v1775606057/san-francisco/production/wvg7jeqdqutgcopdhuwv.jpg'},
#   'data_as_of': '2026-06-08T01:00:00.000',
#   'data_loaded_at': '2026-06-08T03:13:41.000'},
#  {'service_request_id': '101004031375',
#   'requested_datetime': '2026-05-10T18:28:23.000',
#   'closed_date': '2026-06-05T11:13:42.000',
#   'updated_datetime': '2026-06-06T11:17:45.000',
#   'status_description': 'Closed',
#   'status_notes': 'Case Resolved',
#   'agency_responsible': 'PW - Street and Environmental Services',
#   'service_name': 'Litter Receptacle Maintenance',
#   'service_subtype': 'toters_left_out_24x7',
#   'address': '675 41ST AVE, SAN FRANCISCO, CA 94121',
#   'street': '41ST AVE',
#   'supervisor_district': '1.0',
#   'neighborhoods_sffind_boundaries': 'Outer Richmond',
#   'analysis_neighborhood': 'Outer Richmond',
#   'police_district': 'RICHMOND',
#   'lat': '37.77600392045798',
#   'long': '-122.50190008431673',
#   'point': {'latitude': '37.77600392045798',
#    'longitude': '-122.50190008431673',
#    'human_address': '{"address": "", "city": "", "state": "", "zip": ""}'},
#   'point_geom': {'type': 'Point',
#    'coordinates': [-122.501900084, 37.77600392]},
#   'source': 'Mobile',
#   'media_url': {'url': 'https://spot-sf-res.cloudinary.com/image/upload/v1778462903/san-francisco/production/u21qajqejvk6ot3jghcj.jpg'},
#   'data_as_of': '2026-06-08T01:00:00.000',
#   'data_loaded_at': '2026-06-08T03:13:41.000'},
#  {'service_request_id': '101003894077',
#   'requested_datetime': '2026-04-18T10:59:22.000',
#   'closed_date': '2026-06-05T11:31:46.000',
#   'updated_datetime': '2026-06-06T11:17:46.000',
#   'status_description': 'Closed',
#   'status_notes': 'Case Resolved',
#   'agency_responsible': 'PW - Street and Environmental Services',
#   'service_name': 'Litter Receptacle Maintenance',
#   'service_subtype': 'toters_left_out_24x7',
#   'address': '3255 BALBOA ST, SAN FRANCISCO, CA 94121',
#   'street': 'BALBOA ST',
#   'supervisor_district': '1.0',
#   'neighborhoods_sffind_boundaries': 'Outer Richmond',
#   'analysis_neighborhood': 'Outer Richmond',
#   'police_district': 'RICHMOND',
#   'lat': '37.77568600989957',
#   'long': '-122.49393329763328',
#   'point': {'latitude': '37.77568600989957',
#    'longitude': '-122.49393329763328',
#    'human_address': '{"address": "", "city": "", "state": "", "zip": ""}'},
#   'point_geom': {'type': 'Point',
#    'coordinates': [-122.493933298, 37.77568601]},
#   'source': 'Mobile',
#   'media_url': {'url': 'https://spot-sf-res.cloudinary.com/image/upload/v1776535161/san-francisco/production/emielv3hgluphyflsvwo.jpg'},
#   'data_as_of': '2026-06-08T01:00:00.000',
#   'data_loaded_at': '2026-06-08T03:13:41.000'},
#  {'service_request_id': '101003745276',
#   'requested_datetime': '2026-03-25T13:59:25.000',
#   'closed_date': '2026-06-05T11:49:48.000',
#   'updated_datetime': '2026-06-06T11:17:47.000',
#   'status_description': 'Closed',
#   'status_notes': 'Case Resolved - serviced tuesday no evidence of complaint during inspection',
#   'agency_responsible': 'PW - Street and Environmental Services',
#   'service_name': 'Litter Receptacle Maintenance',
#   'service_subtype': 'toters_left_out_24x7',
#   'address': '15 BURLWOOD DR, SAN FRANCISCO, CA 94127',
#   'street': 'BURLWOOD DR',
#   'supervisor_district': '7.0',
#   'neighborhoods_sffind_boundaries': 'Sherwood Forest',
#   'analysis_neighborhood': 'West of Twin Peaks',
#   'police_district': 'INGLESIDE',
#   'lat': '37.73500718411745',
#   'long': '-122.45505886723973',
#   'point': {'latitude': '37.73500718411745',
#    'longitude': '-122.45505886723973',
#    'human_address': '{"address": "", "city": "", "state": "", "zip": ""}'},
#   'point_geom': {'type': 'Point',
#    'coordinates': [-122.455058867, 37.735007184]},
#   'source': 'Mobile',
#   'media_url': {'url': 'https://spot-sf-res.cloudinary.com/image/upload/v1774472364/san-francisco/production/oknc0pehdbb4kzmr8cga.jpg'},
#   'data_as_of': '2026-06-08T01:00:00.000',
#   'data_loaded_at': '2026-06-08T03:13:41.000'},
#  {'service_request_id': '101003891050',
#   'requested_datetime': '2026-04-17T16:49:49.000',
#   'closed_date': '2026-06-05T11:18:25.000',
#   'updated_datetime': '2026-06-06T11:17:48.000',
#   'status_description': 'Closed',
#   'status_notes': 'Case Resolved - Outreach and Enforcement Incident created.   Outreach and Enforcement Incident created.',
#   'agency_responsible': 'PW - Street and Environmental Services',
#   'service_name': 'Litter Receptacle Maintenance',
#   'service_subtype': 'toters_left_out_24x7',
#   'address': '162 ARCH ST, SAN FRANCISCO, CA 94132',
#   'street': 'ARCH ST',
#   'supervisor_district': '11.0',
#   'neighborhoods_sffind_boundaries': 'Merced Heights',
#   'analysis_neighborhood': 'Oceanview/Merced/Ingleside',
#   'police_district': 'TARAVAL',
#   'lat': '37.71364055',
#   'long': '-122.46694525',
#   'point': {'latitude': '37.71364055',
#    'longitude': '-122.46694525',
#    'human_address': '{"address": "", "city": "", "state": "", "zip": ""}'},
#   'point_geom': {'type': 'Point', 'coordinates': [-122.46694525, 37.71364055]},
#   'source': 'Phone',
#   'data_as_of': '2026-06-08T01:00:00.000',
#   'data_loaded_at': '2026-06-08T03:13:41.000'},
#  {'service_request_id': '101004110195',
#   'requested_datetime': '2026-05-22T15:32:52.000',
#   'closed_date': '2026-06-05T11:57:19.000',
#   'updated_datetime': '2026-06-06T11:17:49.000',
#   'status_description': 'Closed',
#   'status_notes': 'Case Resolved - NOV issued at location',
#   'agency_responsible': 'PW - Street and Environmental Services',
#   'service_name': 'Litter Receptacle Maintenance',
#   'service_subtype': 'toters_left_out_24x7',
#   'address': '580 MISSION BAY BLVD NORTH, SAN FRANCISCO, CA 94158',
#   'street': 'MISSION BAY BLVD NORTH',
#   'supervisor_district': '6.0',
#   'neighborhoods_sffind_boundaries': 'Mission Bay',
#   'analysis_neighborhood': 'Mission Bay',
#   'police_district': 'SOUTHERN',
#   'lat': '37.77111477',
#   'long': '-122.39081233',
#   'point': {'latitude': '37.77111477',
#    'longitude': '-122.39081233',
#    'human_address': '{"address": "", "city": "", "state": "", "zip": ""}'},
#   'point_geom': {'type': 'Point', 'coordinates': [-122.39081233, 37.77111477]},
#   'source': 'Web',
#   'media_url': {'url': 'https://sanfrancisco.form.us.empro.verintcloudservices.com/form/auto/download_attachments?caseid=101004110195&formref=LXL9XXH5'},
#   'data_as_of': '2026-06-08T01:00:00.000',
#   'data_loaded_at': '2026-06-08T03:13:41.000'},
#  ...]
