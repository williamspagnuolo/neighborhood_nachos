# %%
import requests
import os
import datetime as dt
import json
from dotenv import load_dotenv
from google.cloud import storage

# %%
load_dotenv()
# Out:
# True

# %%
query_date = str(dt.date.today() - dt.timedelta(days= 2))

url = f"https://data.sfgov.org/resource/vw6y-z8j6.json?$where=updated_datetime>='{query_date}'&$limit=999999"
response = requests.get(url)
items = response.json()

# %%
bucket_name = os.environ.get("GCS_BUCKET_NAME")
service_acct = os.environ.get("GCS_BUCKET_CREDENTIALS")

client = storage.Client.from_service_account_json(service_acct)
bucket = client.bucket(bucket_name)

json_data = json.dumps(items, indent=4)

blob = bucket.blob(f'{query_date}_311_api_call')
blob.upload_from_string(json_data)

# %%
json_name = f'{query_date}_311_api_call'

json_string = blob.download_as_text()
json_try = json.loads(json_string)

# %%
json_try
# Out:
# [{'service_request_id': '101004238527',
#   'requested_datetime': '2026-06-12T13:24:00.000',
#   'closed_date': '2026-06-13T00:00:03.000',
#   'updated_datetime': '2026-06-13T00:00:03.000',
#   'status_description': 'Closed',
#   'status_notes': 'Unable to Locate',
#   'agency_responsible': 'Healthy Streets Operation Center',
#   'service_name': 'Encampment',
#   'service_subtype': 'encampment',
#   'address': '1147 MISSION ST, SAN FRANCISCO, CA 94103',
#   'street': 'MISSION ST',
#   'supervisor_district': '6.0',
#   'neighborhoods_sffind_boundaries': 'South of Market',
#   'analysis_neighborhood': 'South of Market',
#   'police_district': 'SOUTHERN',
#   'lat': '37.77831595899138',
#   'long': '-122.41192452521253',
#   'point': {'latitude': '37.77831595899138',
#    'longitude': '-122.41192452521253',
#    'human_address': '{"address": "", "city": "", "state": "", "zip": ""}'},
#   'point_geom': {'type': 'Point',
#    'coordinates': [-122.411924525, 37.778315959]},
#   'source': 'Mobile',
#   'media_url': {'url': 'https://spot-sf-res.cloudinary.com/image/upload/v1781295840/san-francisco/production/fchwrijftaoylscz05lo.jpg'},
#   'data_as_of': '2026-06-15T01:00:00.000',
#   'data_loaded_at': '2026-06-15T03:13:26.000'},
#  {'service_request_id': '101004241363',
#   'requested_datetime': '2026-06-13T00:01:44.000',
#   'updated_datetime': '2026-06-13T00:01:44.000',
#   'status_description': 'Open',
#   'status_notes': 'open',
#   'agency_responsible': 'DPH Environmental Health',
#   'service_name': 'General Request',
#   'service_subtype': 'public_health',
#   'service_details': 'environmental_health complaint',
#   'address': '1131 POLK ST, SAN FRANCISCO, CA 94109',
#   'street': 'POLK ST',
#   'supervisor_district': '3.0',
#   'neighborhoods_sffind_boundaries': 'Lower Nob Hill',
#   'analysis_neighborhood': 'Nob Hill',
#   'police_district': 'NORTHERN',
#   'lat': '37.78749213',
#   'long': '-122.42020053',
#   'point': {'latitude': '37.78749213',
#    'longitude': '-122.42020053',
#    'human_address': '{"address": "", "city": "", "state": "", "zip": ""}'},
#   'point_geom': {'type': 'Point', 'coordinates': [-122.42020053, 37.78749213]},
#   'source': 'Phone',
#   'data_as_of': '2026-06-15T01:00:00.000',
#   'data_loaded_at': '2026-06-15T03:13:26.000'},
#  {'service_request_id': '101004241367',
#   'requested_datetime': '2026-06-13T00:04:26.000',
#   'updated_datetime': '2026-06-13T00:04:35.000',
#   'status_description': 'Open',
#   'status_notes': 'open',
#   'agency_responsible': 'Noise Report',
#   'service_name': 'Noise',
#   'service_subtype': 'other_excessive_noise',
#   'address': '5800 GEARY BLVD, SAN FRANCISCO, CA 94121',
#   'street': 'GEARY BLVD',
#   'supervisor_district': '1.0',
#   'neighborhoods_sffind_boundaries': 'Outer Richmond',
#   'analysis_neighborhood': 'Outer Richmond',
#   'police_district': 'RICHMOND',
#   'lat': '37.78042893786258',
#   'long': '-122.48171970286998',
#   'point': {'latitude': '37.78042893786258',
#    'longitude': '-122.48171970286998',
#    'human_address': '{"address": "", "city": "", "state": "", "zip": ""}'},
#   'point_geom': {'type': 'Point',
#    'coordinates': [-122.481719703, 37.780428938]},
#   'source': 'Mobile',
#   'data_as_of': '2026-06-15T01:00:00.000',
#   'data_loaded_at': '2026-06-15T03:13:26.000'},
#  {'service_request_id': '101004241199',
#   'requested_datetime': '2026-06-12T22:10:59.000',
#   'updated_datetime': '2026-06-13T00:06:03.000',
#   'status_description': 'Open',
#   'status_notes': 'open',
#   'agency_responsible': 'Healthy Streets Operation Center',
#   'service_name': 'Encampment',
#   'service_subtype': 'encampment',
#   'address': '520 JONES ST, SAN FRANCISCO, CA 94102',
#   'street': 'JONES ST',
#   'supervisor_district': '5.0',
#   'neighborhoods_sffind_boundaries': 'Tenderloin',
#   'analysis_neighborhood': 'Tenderloin',
#   'police_district': 'TENDERLOIN',
#   'lat': '37.78607342',
#   'long': '-122.4128682',
#   'point': {'latitude': '37.78607342',
#    'longitude': '-122.4128682',
#    'human_address': '{"address": "", "city": "", "state": "", "zip": ""}'},
#   'point_geom': {'type': 'Point', 'coordinates': [-122.4128682, 37.78607342]},
#   'source': 'Web',
#   'media_url': {'url': 'https://sanfrancisco.form.us.empro.verintcloudservices.com/form/auto/download_attachments?caseid=101004241199&formref=I9Y29ST4'},
#   'data_as_of': '2026-06-15T01:00:00.000',
#   'data_loaded_at': '2026-06-15T03:13:26.000'},
#  {'service_request_id': '101004240534',
#   'requested_datetime': '2026-06-12T18:51:02.000',
#   'closed_date': '2026-06-13T00:10:27.000',
#   'updated_datetime': '2026-06-13T00:10:27.000',
#   'status_description': 'Closed',
#   'status_notes': 'Unable to Locate',
#   'agency_responsible': 'Healthy Streets Operation Center',
#   'service_name': 'Encampment',
#   'service_subtype': 'encampment',
#   'address': '85 ALBION ST, SAN FRANCISCO, CA 94103',
#   'street': 'ALBION ST',
#   'supervisor_district': '9.0',
#   'neighborhoods_sffind_boundaries': 'Mission Dolores',
#   'analysis_neighborhood': 'Mission',
#   'police_district': 'MISSION',
#   'lat': '37.765274832929215',
#   'long': '-122.42304009323476',
#   'point': {'latitude': '37.765274832929215',
#    'longitude': '-122.42304009323476',
#    'human_address': '{"address": "", "city": "", "state": "", "zip": ""}'},
#   'point_geom': {'type': 'Point',
#    'coordinates': [-122.423040093, 37.765274833]},
#   'source': 'Mobile',
#   'data_as_of': '2026-06-15T01:00:00.000',
#   'data_loaded_at': '2026-06-15T03:13:26.000'},
#  {'service_request_id': '101004241374',
#   'requested_datetime': '2026-06-13T00:12:43.000',
#   'updated_datetime': '2026-06-13T00:12:49.000',
#   'status_description': 'Open',
#   'status_notes': 'open',
#   'agency_responsible': 'Noise Report',
#   'service_name': 'Noise',
#   'service_subtype': 'other_excessive_noise',
#   'address': '981 COLUMBUS AVE, SAN FRANCISCO, CA 94133',
#   'street': 'COLUMBUS AVE',
#   'supervisor_district': '3.0',
#   'neighborhoods_sffind_boundaries': 'Russian Hill',
#   'analysis_neighborhood': 'Russian Hill',
#   'police_district': 'CENTRAL',
#   'lat': '37.803222321597495',
#   'long': '-122.4147437939366',
#   'point': {'latitude': '37.803222321597495',
#    'longitude': '-122.4147437939366',
#    'human_address': '{"address": "", "city": "", "state": "", "zip": ""}'},
#   'point_geom': {'type': 'Point',
#    'coordinates': [-122.414743794, 37.803222322]},
#   'source': 'Mobile',
#   'data_as_of': '2026-06-15T01:00:00.000',
#   'data_loaded_at': '2026-06-15T03:13:26.000'},
#  {'service_request_id': '101004236718',
#   'requested_datetime': '2026-06-12T09:56:53.000',
#   'closed_date': '2026-06-13T00:16:30.000',
#   'updated_datetime': '2026-06-13T00:16:30.000',
#   'status_description': 'Closed',
#   'status_notes': 'Case Resolved',
#   'agency_responsible': 'Healthy Streets Operation Center',
#   'service_name': 'General Request',
#   'service_subtype': 'homelessness_and_supportive_housing',
#   'service_details': 'housing_homeless request_for_service',
#   'address': '33 CEDAR ST, SAN FRANCISCO, CA 94109',
#   'street': 'CEDAR ST',
#   'supervisor_district': '6.0',
#   'neighborhoods_sffind_boundaries': 'Lower Nob Hill',
#   'analysis_neighborhood': 'Tenderloin',
#   'police_district': 'NORTHERN',
#   'lat': '37.7864114',
#   'long': '-122.4187495',
#   'point': {'latitude': '37.7864114',
#    'longitude': '-122.4187495',
#    'human_address': '{"address": "", "city": "", "state": "", "zip": ""}'},
#   'point_geom': {'type': 'Point', 'coordinates': [-122.4187495, 37.7864114]},
#   'source': 'Web',
#   'media_url': {'url': 'https://sanfrancisco.form.us.empro.verintcloudservices.com/form/auto/download_attachments?caseid=101004236718&formref=OFH3XDZ8'},
#   'data_as_of': '2026-06-15T01:00:00.000',
#   'data_loaded_at': '2026-06-15T03:13:26.000'},
#  {'service_request_id': '101004236374',
#   'requested_datetime': '2026-06-12T09:19:53.000',
#   'closed_date': '2026-06-13T00:16:50.000',
#   'updated_datetime': '2026-06-13T00:16:50.000',
#   'status_description': 'Closed',
#   'status_notes': 'Case Resolved',
#   'agency_responsible': 'Healthy Streets Operation Center',
#   'service_name': 'Encampment',
#   'service_subtype': 'encampment',
#   'address': '2245 QUESADA AVE, SAN FRANCISCO, CA 94124',
#   'street': 'QUESADA AVE',
#   'supervisor_district': '10.0',
#   'neighborhoods_sffind_boundaries': 'Apparel City',
#   'analysis_neighborhood': 'Bayview Hunters Point',
#   'police_district': 'BAYVIEW',
#   'lat': '37.73904449',
#   'long': '-122.40180734',
#   'point': {'latitude': '37.73904449',
#    'longitude': '-122.40180734',
#    'human_address': '{"address": "", "city": "", "state": "", "zip": ""}'},
#   'point_geom': {'type': 'Point', 'coordinates': [-122.40180734, 37.73904449]},
#   'source': 'Web',
#   'media_url': {'url': 'https://sanfrancisco.form.us.empro.verintcloudservices.com/form/auto/download_attachments?caseid=101004236374&formref=JC964A26'},
#   'data_as_of': '2026-06-15T01:00:00.000',
#   'data_loaded_at': '2026-06-15T03:13:26.000'},
#  {'service_request_id': '101004235644',
#   'requested_datetime': '2026-06-12T08:11:15.000',
#   'closed_date': '2026-06-13T00:17:27.000',
#   'updated_datetime': '2026-06-13T00:17:27.000',
#   'status_description': 'Closed',
#   'status_notes': 'Unable to Locate',
#   'agency_responsible': 'Healthy Streets Operation Center',
#   'service_name': 'Encampment',
#   'service_subtype': 'encampment',
#   'address': '260 EDDY ST, SAN FRANCISCO, CA 94102',
#   'street': 'EDDY ST',
#   'supervisor_district': '5.0',
#   'neighborhoods_sffind_boundaries': 'Tenderloin',
#   'analysis_neighborhood': 'Tenderloin',
#   'police_district': 'TENDERLOIN',
#   'lat': '37.78407316159291',
#   'long': '-122.41208387802097',
#   'point': {'latitude': '37.78407316159291',
#    'longitude': '-122.41208387802097',
#    'human_address': '{"address": "", "city": "", "state": "", "zip": ""}'},
#   'point_geom': {'type': 'Point',
#    'coordinates': [-122.412083878, 37.784073162]},
#   'source': 'Mobile',
#   'media_url': {'url': 'https://spot-sf-res.cloudinary.com/image/upload/v1781277074/san-francisco/production/lvusyuhzl1cu2mxvkcmz.jpg'},
#   'data_as_of': '2026-06-15T01:00:00.000',
#   'data_loaded_at': '2026-06-15T03:13:26.000'},
#  {'service_request_id': '101004235983',
#   'requested_datetime': '2026-06-12T08:45:07.000',
#   'closed_date': '2026-06-13T00:18:01.000',
#   'updated_datetime': '2026-06-13T00:18:01.000',
#   'status_description': 'Closed',
#   'status_notes': 'Case Cancelled - Caltrans',
#   'agency_responsible': 'Healthy Streets Operation Center',
#   'service_name': 'Encampment',
#   'service_subtype': 'encampment',
#   'address': 'INTERSECTION I-280 S ON RAMP, MARIPOSA ST, SAN FRANCISCO, CA 94107',
#   'street': 'I-280 S ON RAMP',
#   'supervisor_district': '10.0',
#   'neighborhoods_sffind_boundaries': 'Potrero Hill',
#   'analysis_neighborhood': 'Potrero Hill',
#   'police_district': 'BAYVIEW',
#   'lat': '37.763997236379325',
#   'long': '-122.39314666566612',
#   'point': {'latitude': '37.763997236379325',
#    'longitude': '-122.39314666566612',
#    'human_address': '{"address": "", "city": "", "state": "", "zip": ""}'},
#   'point_geom': {'type': 'Point',
#    'coordinates': [-122.393146666, 37.763997236]},
#   'source': 'Mobile',
#   'media_url': {'url': 'https://spot-sf-res.cloudinary.com/image/upload/v1781279105/san-francisco/production/pkadoony1hffpo5h1m3b.jpg'},
#   'data_as_of': '2026-06-15T01:00:00.000',
#   'data_loaded_at': '2026-06-15T03:13:26.000'},
#  {'service_request_id': '101004235466',
#   'requested_datetime': '2026-06-12T07:49:43.000',
#   'closed_date': '2026-06-13T00:18:16.000',
#   'updated_datetime': '2026-06-13T00:18:17.000',
#   'status_description': 'Closed',
#   'status_notes': 'Case Resolved',
#   'agency_responsible': 'Healthy Streets Operation Center',
#   'service_name': 'Encampment',
#   'service_subtype': 'encampment',
#   'address': 'INTERSECTION STOCKTON ST, BUSH ST, SAN FRANCISCO, CA 94108',
#   'street': 'STOCKTON ST',
#   'supervisor_district': '3.0',
#   'neighborhoods_sffind_boundaries': 'Downtown / Union Square',
#   'analysis_neighborhood': 'Financial District/South Beach',
#   'police_district': 'CENTRAL',
#   'lat': '37.7903683671',
#   'long': '-122.407131822',
#   'point': {'latitude': '37.7903683671',
#    'longitude': '-122.407131822',
#    'human_address': '{"address": "", "city": "", "state": "", "zip": ""}'},
#   'point_geom': {'type': 'Point',
#    'coordinates': [-122.407131822, 37.790368367]},
#   'source': 'Phone',
#   'data_as_of': '2026-06-15T01:00:00.000',
#   'data_loaded_at': '2026-06-15T03:13:26.000'},
#  {'service_request_id': '101004241397',
#   'requested_datetime': '2026-06-13T00:32:35.000',
#   'updated_datetime': '2026-06-13T00:32:35.000',
#   'status_description': 'Open',
#   'status_notes': 'open',
#   'agency_responsible': 'Noise Report',
#   'service_name': 'Noise',
#   'service_subtype': 'amplified_sound_electronics',
#   'address': '337 HYDE ST, SAN FRANCISCO, CA 94109',
#   'street': 'HYDE ST',
#   'supervisor_district': '5.0',
#   'neighborhoods_sffind_boundaries': 'Tenderloin',
#   'analysis_neighborhood': 'Tenderloin',
#   'police_district': 'TENDERLOIN',
#   'lat': '37.78401862',
#   'long': '-122.41611682',
#   'point': {'latitude': '37.78401862',
#    'longitude': '-122.41611682',
#    'human_address': '{"address": "", "city": "", "state": "", "zip": ""}'},
#   'point_geom': {'type': 'Point', 'coordinates': [-122.41611682, 37.78401862]},
#   'source': 'Web',
#   'data_as_of': '2026-06-15T01:00:00.000',
#   'data_loaded_at': '2026-06-15T03:13:26.000'},
#  {'service_request_id': '101004235506',
#   'requested_datetime': '2026-06-12T07:54:56.000',
#   'closed_date': '2026-06-13T00:33:59.000',
#   'updated_datetime': '2026-06-13T00:33:59.000',
#   'status_description': 'Closed',
#   'status_notes': 'Case Cancelled - Caltrans',
#   'agency_responsible': 'Healthy Streets Operation Center',
#   'service_name': 'Encampment',
#   'service_subtype': 'encampment',
#   'address': '301 BRYANT ST, SAN FRANCISCO, CA 94107',
#   'street': 'BRYANT ST',
#   'supervisor_district': '6.0',
#   'neighborhoods_sffind_boundaries': 'South Beach',
#   'analysis_neighborhood': 'Financial District/South Beach',
#   'police_district': 'SOUTHERN',
#   'lat': '37.78455978',
#   'long': '-122.39147699',
#   'point': {'latitude': '37.78455978',
#    'longitude': '-122.39147699',
#    'human_address': '{"address": "", "city": "", "state": "", "zip": ""}'},
#   'point_geom': {'type': 'Point', 'coordinates': [-122.39147699, 37.78455978]},
#   'source': 'Phone',
#   'data_as_of': '2026-06-15T01:00:00.000',
#   'data_loaded_at': '2026-06-15T03:13:26.000'},
#  {'service_request_id': '101004241391',
#   'requested_datetime': '2026-06-13T00:27:25.000',
#   'updated_datetime': '2026-06-13T00:36:40.000',
#   'status_description': 'Open',
#   'status_notes': 'open',
#   'agency_responsible': 'MTA - Muni Feedback Received',
#   'service_name': 'Muni Service Feedback',
#   'service_subtype': 'complaint_frequency_reliability',
#   'service_details': 'pass_ups',
#   'address': 'INTERSECTION 4TH ST, KING ST, SAN FRANCISCO, CA 94158',
#   'street': '4TH ST',
#   'supervisor_district': '6.0',
#   'neighborhoods_sffind_boundaries': 'Mission Bay',
#   'analysis_neighborhood': 'Mission Bay',
#   'police_district': 'SOUTHERN',
#   'lat': '37.7763329628',
#   'long': '-122.3940350659',
#   'point': {'latitude': '37.7763329628',
#    'longitude': '-122.3940350659',
#    'human_address': '{"address": "", "city": "", "state": "", "zip": ""}'},
#   'point_geom': {'type': 'Point',
#    'coordinates': [-122.394035066, 37.776332963]},
#   'source': 'Phone',
#   'data_as_of': '2026-06-15T01:00:00.000',
#   'data_loaded_at': '2026-06-15T03:13:26.000'},
#  {'service_request_id': '101004241224',
#   'requested_datetime': '2026-06-12T22:26:40.000',
#   'closed_date': '2026-06-13T01:38:31.000',
#   'updated_datetime': '2026-06-13T00:38:36.000',
#   'status_description': 'Closed',
#   'status_notes': 'Case Resolved - Officer responded to request under CAD # 261633910. Issue was addressed.',
#   'agency_responsible': 'MTA - Parking Enforcement Dispatch',
#   'service_name': 'Parking Enforcement',
#   'service_subtype': 'blocking_driveway_cite_only',
#   'address': '848 26TH AVE, SAN FRANCISCO, CA 94121',
#   'street': '26TH AVE',
#   'supervisor_district': '1.0',
#   'neighborhoods_sffind_boundaries': 'Outer Richmond',
#   'analysis_neighborhood': 'Outer Richmond',
#   'police_district': 'RICHMOND',
#   'lat': '37.77349029437939',
#   'long': '-122.48525463044645',
#   'point': {'latitude': '37.77349029437939',
#    'longitude': '-122.48525463044645',
#    'human_address': '{"address": "", "city": "", "state": "", "zip": ""}'},
#   'point_geom': {'type': 'Point',
#    'coordinates': [-122.48525463, 37.773490294]},
#   'source': 'Mobile',
#   'media_url': {'url': 'https://spot-sf-res.cloudinary.com/image/upload/v1781328399/san-francisco/production/lqtk6y0udqwqdwaajud5.jpg'},
#   'data_as_of': '2026-06-15T01:00:00.000',
#   'data_loaded_at': '2026-06-15T03:13:26.000'},
#  {'service_request_id': '101004241389',
#   'requested_datetime': '2026-06-13T00:24:31.000',
#   'updated_datetime': '2026-06-13T00:40:32.000',
#   'status_description': 'Open',
#   'status_notes': 'open',
#   'agency_responsible': 'PW - Street and Environmental Services',
#   'service_name': 'Graffiti Private',
#   'service_subtype': 'not_offensive',
#   'service_details': 'sidewalk_in_front_of_property',
#   'address': '80 JULIAN AVE, SAN FRANCISCO, CA 94103',
#   'street': 'JULIAN AVE',
#   'supervisor_district': '9.0',
#   'neighborhoods_sffind_boundaries': 'Mission',
#   'analysis_neighborhood': 'Mission',
#   'police_district': 'MISSION',
#   'lat': '37.76699302',
#   'long': '-122.42121585',
#   'point': {'latitude': '37.76699302',
#    'longitude': '-122.42121585',
#    'human_address': '{"address": "", "city": "", "state": "", "zip": ""}'},
#   'point_geom': {'type': 'Point', 'coordinates': [-122.42121585, 37.76699302]},
#   'source': 'Phone',
#   'data_as_of': '2026-06-15T01:00:00.000',
#   'data_loaded_at': '2026-06-15T03:13:26.000'},
#  {'service_request_id': '101004241356',
#   'requested_datetime': '2026-06-12T23:53:46.000',
#   'updated_datetime': '2026-06-13T00:40:41.000',
#   'status_description': 'Open',
#   'status_notes': 'open',
#   'agency_responsible': 'PW - Street Use and Mapping',
#   'service_name': 'Sidewalk and Curb',
#   'service_subtype': 'other',
#   'address': '3626 FOLSOM ST, SAN FRANCISCO, CA 94110',
#   'street': 'FOLSOM ST',
#   'supervisor_district': '9.0',
#   'neighborhoods_sffind_boundaries': 'Bernal Heights',
#   'analysis_neighborhood': 'Bernal Heights',
#   'police_district': 'INGLESIDE',
#   'lat': '37.74101930100836',
#   'long': '-122.41329256675088',
#   'point': {'latitude': '37.74101930100836',
#    'longitude': '-122.41329256675088',
#    'human_address': '{"address": "", "city": "", "state": "", "zip": ""}'},
#   'point_geom': {'type': 'Point',
#    'coordinates': [-122.413292567, 37.741019301]},
#   'source': 'Mobile',
#   'media_url': {'url': 'https://spot-sf-res.cloudinary.com/image/upload/v1781333622/san-francisco/production/sovbjhtv5d75jasu5o4m.jpg'},
#   'data_as_of': '2026-06-15T01:00:00.000',
#   'data_loaded_at': '2026-06-15T03:13:26.000'},
#  {'service_request_id': '101004241349',
#   'requested_datetime': '2026-06-12T23:49:59.000',
#   'closed_date': '2026-06-13T01:41:27.000',
#   'updated_datetime': '2026-06-13T00:41:30.000',
#   'status_description': 'Closed',
#   'status_notes': 'Case Resolved - See CAD# 261634089 for details.',
#   'agency_responsible': 'MTA - Parking Enforcement Dispatch',
#   'service_name': 'Parking Enforcement',
#   'service_subtype': 'blocking_driveway_cite_only',
#   'address': '182 LEXINGTON ST, SAN FRANCISCO, CA 94110',
#   'street': 'LEXINGTON ST',
#   'supervisor_district': '9.0',
#   'neighborhoods_sffind_boundaries': 'Mission',
#   'analysis_neighborhood': 'Mission',
#   'police_district': 'MISSION',
#   'lat': '37.76041618',
#   'long': '-122.42082403',
#   'point': {'latitude': '37.76041618',
#    'longitude': '-122.42082403',
#    'human_address': '{"address": "", "city": "", "state": "", "zip": ""}'},
#   'point_geom': {'type': 'Point', 'coordinates': [-122.42082403, 37.76041618]},
#   'source': 'Phone',
#   'data_as_of': '2026-06-15T01:00:00.000',
#   'data_loaded_at': '2026-06-15T03:13:26.000'},
#  {'service_request_id': '101004241384',
#   'requested_datetime': '2026-06-13T00:17:36.000',
#   'closed_date': '2026-06-13T01:44:22.000',
#   'updated_datetime': '2026-06-13T00:44:26.000',
#   'status_description': 'Closed',
#   'status_notes': 'Case Resolved - See CAD# 261640044 for details.',
#   'agency_responsible': 'MTA - Parking Enforcement Dispatch',
#   'service_name': 'Parking Enforcement',
#   'service_subtype': 'other_illegal_parking',
#   'address': '1998 25TH ST, SAN FRANCISCO, CA 94107',
#   'street': '25TH ST',
#   'supervisor_district': '10.0',
#   'neighborhoods_sffind_boundaries': 'Potrero Hill',
#   'analysis_neighborhood': 'Potrero Hill',
#   'police_district': 'BAYVIEW',
#   'lat': '37.75233879501872',
#   'long': '-122.39842280745506',
#   'point': {'latitude': '37.75233879501872',
#    'longitude': '-122.39842280745506',
#    'human_address': '{"address": "", "city": "", "state": "", "zip": ""}'},
#   'point_geom': {'type': 'Point',
#    'coordinates': [-122.398422807, 37.752338795]},
#   'source': 'Mobile',
#   'data_as_of': '2026-06-15T01:00:00.000',
#   'data_loaded_at': '2026-06-15T03:13:26.000'},
#  {'service_request_id': '101004241414',
#   'requested_datetime': '2026-06-13T00:46:48.000',
#   'updated_datetime': '2026-06-13T00:46:49.000',
#   'status_description': 'Open',
#   'status_notes': 'open',
#   'agency_responsible': 'MTA - Transportation Engineering',
#   'service_name': 'General Request',
#   'service_subtype': 'municipal_transportation_agency',
#   'service_details': 'transportation_engineering request_for_service',
#   'address': 'INTERSECTION SAN JOSE AVE, TINGLEY ST, SAN FRANCISCO, CA 94112',
#   'street': 'SAN JOSE AVE',
#   'supervisor_district': '11.0',
#   'neighborhoods_sffind_boundaries': 'Mission Terrace',
#   'analysis_neighborhood': 'Outer Mission',
#   'police_district': 'INGLESIDE',
#   'lat': '37.7306934',
#   'long': '-122.4356406086',
#   'point': {'latitude': '37.7306934',
#    'longitude': '-122.4356406086',
#    'human_address': '{"address": "", "city": "", "state": "", "zip": ""}'},
#   'point_geom': {'type': 'Point', 'coordinates': [-122.435640609, 37.7306934]},
#   'source': 'Web',
#   'media_url': {'url': 'https://sanfrancisco.form.us.empro.verintcloudservices.com/form/auto/download_attachments?caseid=101004241414&formref=DBD0E4D3'},
#   'data_as_of': '2026-06-15T01:00:00.000',
#   'data_loaded_at': '2026-06-15T03:13:26.000'},
#  {'service_request_id': '101004236935',
#   'requested_datetime': '2026-06-12T10:18:30.000',
#   'updated_datetime': '2026-06-13T00:47:18.000',
#   'status_description': 'Open',
#   'status_notes': 'in progress',
#   'agency_responsible': 'PW - Street and Environmental Services',
#   'service_name': 'Encampment',
#   'service_subtype': 'encampment',
#   'address': '25 RANKIN ST, SAN FRANCISCO, CA 94124',
#   'street': 'RANKIN ST',
#   'supervisor_district': '10.0',
#   'neighborhoods_sffind_boundaries': 'Central Waterfront',
#   'analysis_neighborhood': 'Bayview Hunters Point',
#   'police_district': 'BAYVIEW',
#   'lat': '37.746687031483724',
#   'long': '-122.39073443471142',
#   'point': {'latitude': '37.746687031483724',
#    'longitude': '-122.39073443471142',
#    'human_address': '{"address": "", "city": "", "state": "", "zip": ""}'},
#   'point_geom': {'type': 'Point',
#    'coordinates': [-122.390734435, 37.746687031]},
#   'source': 'Mobile',
#   'media_url': {'url': 'https://spot-sf-res.cloudinary.com/image/upload/v1781284709/san-francisco/production/gtzqainypgpdabnm1h2g.jpg'},
#   'data_as_of': '2026-06-15T01:00:00.000',
#   'data_loaded_at': '2026-06-15T03:13:26.000'},
#  {'service_request_id': '101004241412',
#   'requested_datetime': '2026-06-13T00:45:19.000',
#   'updated_datetime': '2026-06-13T00:49:08.000',
#   'status_description': 'Open',
#   'status_notes': 'accepted',
#   'agency_responsible': 'PUC - Water Quality Report',
#   'service_name': 'Water Quality',
#   'service_subtype': 'bad_taste',
#   'service_details': 'residence',
#   'address': '770 CALIFORNIA ST, SAN FRANCISCO, CA 94108',
#   'street': 'CALIFORNIA ST',
#   'supervisor_district': '3.0',
#   'neighborhoods_sffind_boundaries': 'Chinatown',
#   'analysis_neighborhood': 'Chinatown',
#   'police_district': 'CENTRAL',
#   'lat': '37.79243287',
#   'long': '-122.40712135',
#   'point': {'latitude': '37.79243287',
#    'longitude': '-122.40712135',
#    'human_address': '{"address": "", "city": "", "state": "", "zip": ""}'},
#   'point_geom': {'type': 'Point', 'coordinates': [-122.40712135, 37.79243287]},
#   'source': 'Phone',
#   'data_as_of': '2026-06-15T01:00:00.000',
#   'data_loaded_at': '2026-06-15T03:13:26.000'},
#  {'service_request_id': '101004241417',
#   'requested_datetime': '2026-06-13T00:49:52.000',
#   'updated_datetime': '2026-06-13T00:49:58.000',
#   'status_description': 'Open',
#   'status_notes': 'open',
#   'agency_responsible': 'Noise Report',
#   'service_name': 'Noise',
#   'service_subtype': 'other_excessive_noise',
#   'address': '1875 UNION ST, SAN FRANCISCO, CA 94123',
#   'street': 'UNION ST',
#   'supervisor_district': '2.0',
#   'neighborhoods_sffind_boundaries': 'Union Street',
#   'analysis_neighborhood': 'Marina',
#   'police_district': 'NORTHERN',
#   'lat': '37.797683051753594',
#   'long': '-122.42999744459141',
#   'point': {'latitude': '37.797683051753594',
#    'longitude': '-122.42999744459141',
#    'human_address': '{"address": "", "city": "", "state": "", "zip": ""}'},
#   'point_geom': {'type': 'Point',
#    'coordinates': [-122.429997445, 37.797683052]},
#   'source': 'Mobile',
#   'data_as_of': '2026-06-15T01:00:00.000',
#   'data_loaded_at': '2026-06-15T03:13:26.000'},
#  {'service_request_id': '101004235311',
#   'requested_datetime': '2026-06-12T07:21:58.000',
#   'updated_datetime': '2026-06-13T00:57:19.000',
#   'status_description': 'Open',
#   'status_notes': 'accepted',
#   'agency_responsible': 'PW - Street and Environmental Services',
#   'service_name': 'Street and Sidewalk Cleaning',
#   'service_subtype': 'garbage_and_debris',
#   'service_details': 'other_loose_garbage_debris_yard_waste',
#   'address': '611 MINNA ST, SAN FRANCISCO, CA 94103',
#   'street': 'MINNA ST',
#   'supervisor_district': '6.0',
#   'neighborhoods_sffind_boundaries': 'South of Market',
#   'analysis_neighborhood': 'South of Market',
#   'police_district': 'SOUTHERN',
#   'lat': '37.77843913',
#   'long': '-122.4106993',
#   'point': {'latitude': '37.77843913',
#    'longitude': '-122.4106993',
#    'human_address': '{"address": "", "city": "", "state": "", "zip": ""}'},
#   'point_geom': {'type': 'Point', 'coordinates': [-122.4106993, 37.77843913]},
#   'source': 'Web',
#   'media_url': {'url': 'https://sanfrancisco.form.us.empro.verintcloudservices.com/form/auto/download_attachments?caseid=101004235311&formref=8OR9HXP9'},
#   'data_as_of': '2026-06-15T01:00:00.000',
#   'data_loaded_at': '2026-06-15T03:13:26.000'},
#  {'service_request_id': '101004241438',
#   'requested_datetime': '2026-06-13T01:17:34.000',
#   'updated_datetime': '2026-06-13T01:17:34.000',
#   'status_description': 'Open',
#   'status_notes': 'open',
#   'agency_responsible': 'MTA - Transportation Engineering',
#   'service_name': 'General Request',
#   'service_subtype': 'municipal_transportation_agency',
#   'service_details': 'transportation_engineering other',
#   'address': '1402 NORIEGA ST, SAN FRANCISCO, CA 94122',
#   'street': 'NORIEGA ST',
#   'supervisor_district': '4.0',
#   'neighborhoods_sffind_boundaries': 'Outer Sunset',
#   'analysis_neighborhood': 'Sunset/Parkside',
#   'police_district': 'TARAVAL',
#   'lat': '37.75418457',
#   'long': '-122.47867127',
#   'point': {'latitude': '37.75418457',
#    'longitude': '-122.47867127',
#    'human_address': '{"address": "", "city": "", "state": "", "zip": ""}'},
#   'point_geom': {'type': 'Point', 'coordinates': [-122.47867127, 37.75418457]},
#   'source': 'Web',
#   'data_as_of': '2026-06-15T01:00:00.000',
#   'data_loaded_at': '2026-06-15T03:13:26.000'},
#  {'service_request_id': '101004241446',
#   'requested_datetime': '2026-06-13T01:22:31.000',
#   'updated_datetime': '2026-06-13T01:22:40.000',
#   'status_description': 'Open',
#   'status_notes': 'open',
#   'agency_responsible': 'Clear Channel - Transit',
#   'service_name': 'Damage Property',
#   'service_subtype': 'transit_shelter_platform',
#   'address': '3416 CESAR CHAVEZ ST, SAN FRANCISCO, CA 94110',
#   'street': 'CESAR CHAVEZ ST',
#   'supervisor_district': '9.0',
#   'neighborhoods_sffind_boundaries': 'Mission',
#   'analysis_neighborhood': 'Mission',
#   'police_district': 'MISSION',
#   'lat': '37.74826745497436',
#   'long': '-122.4186069770034',
#   'point': {'latitude': '37.74826745497436',
#    'longitude': '-122.4186069770034',
#    'human_address': '{"address": "", "city": "", "state": "", "zip": ""}'},
#   'point_geom': {'type': 'Point',
#    'coordinates': [-122.418606977, 37.748267455]},
#   'source': 'Mobile',
#   'media_url': {'url': 'https://spot-sf-res.cloudinary.com/image/upload/v1781338950/san-francisco/production/gpbujkxonelqoxh35rjf.jpg'},
#   'data_as_of': '2026-06-15T01:00:00.000',
#   'data_loaded_at': '2026-06-15T03:13:26.000'},
#  {'service_request_id': '101004241447',
#   'requested_datetime': '2026-06-13T01:24:15.000',
#   'updated_datetime': '2026-06-13T01:24:15.000',
#   'status_description': 'Open',
#   'status_notes': 'open',
#   'agency_responsible': 'MTA - Abandoned Vehicles Work',
#   'service_name': 'Parking Enforcement',
#   'service_subtype': 'abandoned_vehicle',
#   'address': '210 COLLEGE AVE, SAN FRANCISCO, CA 94112',
#   'street': 'COLLEGE AVE',
#   'supervisor_district': '9.0',
#   'neighborhoods_sffind_boundaries': "St. Mary's Park",
#   'analysis_neighborhood': 'Bernal Heights',
#   'police_district': 'INGLESIDE',
#   'lat': '37.73522322',
#   'long': '-122.42465045',
#   'point': {'latitude': '37.73522322',
#    'longitude': '-122.42465045',
#    'human_address': '{"address": "", "city": "", "state": "", "zip": ""}'},
#   'point_geom': {'type': 'Point', 'coordinates': [-122.42465045, 37.73522322]},
#   'source': 'Phone',
#   'data_as_of': '2026-06-15T01:00:00.000',
#   'data_loaded_at': '2026-06-15T03:13:26.000'},
#  {'service_request_id': '101004241456',
#   'requested_datetime': '2026-06-13T01:33:02.000',
#   'updated_datetime': '2026-06-13T01:33:03.000',
#   'status_description': 'Open',
#   'status_notes': 'open',
#   'agency_responsible': 'MTA - Abandoned Vehicles Work',
#   'service_name': 'Parking Enforcement',
#   'service_subtype': 'abandoned_vehicle',
#   'address': '210 COLLEGE AVE, SAN FRANCISCO, CA 94112',
#   'street': 'COLLEGE AVE',
#   'supervisor_district': '9.0',
#   'neighborhoods_sffind_boundaries': "St. Mary's Park",
#   'analysis_neighborhood': 'Bernal Heights',
#   'police_district': 'INGLESIDE',
#   'lat': '37.73522322',
#   'long': '-122.42465045',
#   'point': {'latitude': '37.73522322',
#    'longitude': '-122.42465045',
#    'human_address': '{"address": "", "city": "", "state": "", "zip": ""}'},
#   'point_geom': {'type': 'Point', 'coordinates': [-122.42465045, 37.73522322]},
#   'source': 'Phone',
#   'data_as_of': '2026-06-15T01:00:00.000',
#   'data_loaded_at': '2026-06-15T03:13:26.000'},
#  {'service_request_id': '101004241460',
#   'requested_datetime': '2026-06-13T01:40:37.000',
#   'updated_datetime': '2026-06-13T01:40:38.000',
#   'status_description': 'Open',
#   'status_notes': 'open',
#   'agency_responsible': 'MTA - Transportation Engineering',
#   'service_name': 'General Request',
#   'service_subtype': 'municipal_transportation_agency',
#   'service_details': 'transportation_engineering request_for_service',
#   'address': 'INTERSECTION COLLEGE AVE, JUSTIN DR, SAN FRANCISCO, CA 94112',
#   'street': 'COLLEGE AVE',
#   'supervisor_district': '9.0',
#   'neighborhoods_sffind_boundaries': "St. Mary's Park",
#   'analysis_neighborhood': 'Bernal Heights',
#   'police_district': 'INGLESIDE',
#   'lat': '37.7345632612',
#   'long': '-122.4238524593',
#   'point': {'latitude': '37.7345632612',
#    'longitude': '-122.4238524593',
#    'human_address': '{"address": "", "city": "", "state": "", "zip": ""}'},
#   'point_geom': {'type': 'Point',
#    'coordinates': [-122.423852459, 37.734563261]},
#   'source': 'Phone',
#   'data_as_of': '2026-06-15T01:00:00.000',
#   'data_loaded_at': '2026-06-15T03:13:26.000'},
#  {'service_request_id': '101004241461',
#   'requested_datetime': '2026-06-13T01:41:20.000',
#   'updated_datetime': '2026-06-13T01:42:01.000',
#   'status_description': 'Open',
#   'status_notes': 'open',
#   'agency_responsible': 'DPH Environmental Health',
#   'service_name': 'Residential Building',
#   'service_subtype': 'infestation_rodent_insect',
#   'address': '146 MCALLISTER ST, SAN FRANCISCO, CA 94102',
#   'street': 'MCALLISTER ST',
#   'supervisor_district': '5.0',
#   'neighborhoods_sffind_boundaries': 'Civic Center',
#   'analysis_neighborhood': 'Tenderloin',
#   'police_district': 'TENDERLOIN',
#   'lat': '37.78093888',
#   'long': '-122.41445842',
#   'point': {'latitude': '37.78093888',
#    'longitude': '-122.41445842',
#    'human_address': '{"address": "", "city": "", "state": "", "zip": ""}'},
#   'point_geom': {'type': 'Point', 'coordinates': [-122.41445842, 37.78093888]},
#   'source': 'Web',
#   'media_url': {'url': 'https://sanfrancisco.form.us.empro.verintcloudservices.com/form/auto/download_attachments?caseid=101004241461&formref=7I240A35'},
#   'data_as_of': '2026-06-15T01:00:00.000',
#   'data_loaded_at': '2026-06-15T03:13:26.000'},
#  {'service_request_id': '101004241455',
#   'requested_datetime': '2026-06-13T01:32:37.000',
#   'updated_datetime': '2026-06-13T01:42:15.000',
#   'status_description': 'Open',
#   'status_notes': 'in progress',
#   'agency_responsible': 'PW - Street and Environmental Services',
#   'service_name': 'Street and Sidewalk Cleaning',
#   'service_subtype': 'garbage_and_debris',
#   'service_details': 'other_loose_garbage_debris_yard_waste',
#   'address': '1284 7TH ST, SAN FRANCISCO, CA 94107',
#   'street': '7TH ST',
#   'supervisor_district': '10.0',
#   'neighborhoods_sffind_boundaries': 'Mission Bay',
#   'analysis_neighborhood': 'Mission Bay',
#   'police_district': 'SOUTHERN',
#   'lat': '37.7678950825921',
#   'long': '-122.39690534770487',
#   'point': {'latitude': '37.7678950825921',
#    'longitude': '-122.39690534770487',
#    'human_address': '{"address": "", "city": "", "state": "", "zip": ""}'},
#   'point_geom': {'type': 'Point',
#    'coordinates': [-122.396905348, 37.767895083]},
#   'source': 'Mobile',
#   'media_url': {'url': 'https://spot-sf-res.cloudinary.com/image/upload/v1781339556/san-francisco/production/obtmkxgwxluikkmgzq6h.jpg'},
#   'data_as_of': '2026-06-15T01:00:00.000',
#   'data_loaded_at': '2026-06-15T03:13:26.000'},
#  {'service_request_id': '101004241467',
#   'requested_datetime': '2026-06-13T01:49:16.000',
#   'updated_datetime': '2026-06-13T01:49:17.000',
#   'status_description': 'Open',
#   'status_notes': 'open',
#   'agency_responsible': 'Noise Report',
#   'service_name': 'Noise',
#   'service_subtype': 'other_excessive_noise',
#   'address': '1755 OFARRELL ST, SAN FRANCISCO, CA 94115',
#   'street': 'OFARRELL ST',
#   'supervisor_district': '5.0',
#   'neighborhoods_sffind_boundaries': 'Western Addition',
#   'analysis_neighborhood': 'Western Addition',
#   'police_district': 'NORTHERN',
#   'lat': '37.78313707',
#   'long': '-122.43359891',
#   'point': {'latitude': '37.78313707',
#    'longitude': '-122.43359891',
#    'human_address': '{"address": "", "city": "", "state": "", "zip": ""}'},
#   'point_geom': {'type': 'Point', 'coordinates': [-122.43359891, 37.78313707]},
#   'source': 'Phone',
#   'data_as_of': '2026-06-15T01:00:00.000',
#   'data_loaded_at': '2026-06-15T03:13:26.000'},
#  {'service_request_id': '101004241470',
#   'requested_datetime': '2026-06-13T02:08:42.000',
#   'updated_datetime': '2026-06-13T02:09:37.000',
#   'status_description': 'Open',
#   'status_notes': 'accepted',
#   'agency_responsible': 'MTA - Parking Enforcement Dispatch',
#   'service_name': 'Parking Enforcement',
#   'service_subtype': 'parking_on_sidewalk',
#   'address': '51 PASADENA ST, SAN FRANCISCO, CA 94134',
#   'street': 'PASADENA ST',
#   'supervisor_district': '10.0',
#   'neighborhoods_sffind_boundaries': 'Sunnydale',
#   'analysis_neighborhood': 'Visitacion Valley',
#   'police_district': 'INGLESIDE',
#   'lat': '37.708867817908434',
#   'long': '-122.41875629872084',
#   'point': {'latitude': '37.708867817908434',
#    'longitude': '-122.41875629872084',
#    'human_address': '{"address": "", "city": "", "state": "", "zip": ""}'},
#   'point_geom': {'type': 'Point',
#    'coordinates': [-122.418756299, 37.708867818]},
#   'source': 'Mobile',
#   'media_url': {'url': 'https://spot-sf-res.cloudinary.com/image/upload/v1781341720/san-francisco/production/gihefry7l5amnyezgcnk.jpg'},
#   'data_as_of': '2026-06-15T01:00:00.000',
#   'data_loaded_at': '2026-06-15T03:13:26.000'},
#  {'service_request_id': '101004241338',
#   'requested_datetime': '2026-06-12T23:43:59.000',
#   'closed_date': '2026-06-13T03:23:08.000',
#   'updated_datetime': '2026-06-13T02:23:12.000',
#   'status_description': 'Closed',
#   'status_notes': 'Case Resolved - Officer responded to request under CAD # 261634078.  Citation was issued.',
#   'agency_responsible': 'MTA - Parking Enforcement Dispatch',
#   'service_name': 'Parking Enforcement',
#   'service_subtype': 'other_illegal_parking',
#   'address': '505 BAKER ST, SAN FRANCISCO, CA 94117',
#   'street': 'BAKER ST',
#   'supervisor_district': '5.0',
#   'neighborhoods_sffind_boundaries': 'Panhandle',
#   'analysis_neighborhood': 'Lone Mountain/USF',
#   'police_district': 'PARK',
#   'lat': '37.77563269668836',
#   'long': '-122.44150299254262',
#   'point': {'latitude': '37.77563269668836',
#    'longitude': '-122.44150299254262',
#    'human_address': '{"address": "", "city": "", "state": "", "zip": ""}'},
#   'point_geom': {'type': 'Point',
#    'coordinates': [-122.441502993, 37.775632697]},
#   'source': 'Mobile',
#   'media_url': {'url': 'https://spot-sf-res.cloudinary.com/image/upload/v1781333038/san-francisco/production/evlcz0ayt5qgwbhyfo8r.jpg'},
#   'data_as_of': '2026-06-15T01:00:00.000',
#   'data_loaded_at': '2026-06-15T03:13:26.000'},
#  {'service_request_id': '101004241478',
#   'requested_datetime': '2026-06-13T02:36:04.000',
#   'updated_datetime': '2026-06-13T02:36:10.000',
#   'status_description': 'Open',
#   'status_notes': 'open',
#   'agency_responsible': 'Noise Report',
#   'service_name': 'Noise',
#   'service_subtype': 'other_excessive_noise',
#   'address': '279 6TH ST, SAN FRANCISCO, CA 94103',
#   'street': '6TH ST',
#   'supervisor_district': '6.0',
#   'neighborhoods_sffind_boundaries': 'South of Market',
#   'analysis_neighborhood': 'South of Market',
#   'police_district': 'SOUTHERN',
#   'lat': '37.77878350180587',
#   'long': '-122.40599252066922',
#   'point': {'latitude': '37.77878350180587',
#    'longitude': '-122.40599252066922',
#    'human_address': '{"address": "", "city": "", "state": "", "zip": ""}'},
#   'point_geom': {'type': 'Point',
#    'coordinates': [-122.405992521, 37.778783502]},
#   'source': 'Mobile',
#   'data_as_of': '2026-06-15T01:00:00.000',
#   'data_loaded_at': '2026-06-15T03:13:26.000'},
#  {'service_request_id': '101004235693',
#   'requested_datetime': '2026-06-12T08:16:20.000',
#   'closed_date': '2026-06-13T02:47:52.000',
#   'updated_datetime': '2026-06-13T02:47:56.000',
#   'status_description': 'Closed',
#   'status_notes': 'Insufficient Information Provi - Proper address or intersection needed in order to service. Please resubmit with the actual location.',
#   'agency_responsible': '311 - Supervisor',
#   'service_name': 'Street and Sidewalk Cleaning',
#   'service_subtype': 'garbage_and_debris',
#   'service_details': 'other_loose_garbage_debris_yard_waste',
#   'address': 'INTERSECTION I-80 W ON RAMP, I-80 WESTBOUND, SAN FRANCISCO, CA 94103',
#   'street': 'I-80 W ON RAMP',
#   'supervisor_district': '6.0',
#   'neighborhoods_sffind_boundaries': 'Showplace Square',
#   'analysis_neighborhood': 'South of Market',
#   'police_district': 'SOUTHERN',
#   'lat': '37.77250195424198',
#   'long': '-122.40674422548862',
#   'point': {'latitude': '37.77250195424198',
#    'longitude': '-122.40674422548862',
#    'human_address': '{"address": "", "city": "", "state": "", "zip": ""}'},
#   'point_geom': {'type': 'Point',
#    'coordinates': [-122.406744225, 37.772501954]},
#   'source': 'Mobile',
#   'media_url': {'url': 'https://spot-sf-res.cloudinary.com/image/upload/v1781277379/san-francisco/production/gzdbxpuvp2dtbuvrfl7k.jpg'},
#   'data_as_of': '2026-06-15T01:00:00.000',
#   'data_loaded_at': '2026-06-15T03:13:26.000'},
#  {'service_request_id': '101004241485',
#   'requested_datetime': '2026-06-13T02:56:29.000',
#   'updated_datetime': '2026-06-13T02:56:38.000',
#   'status_description': 'Open',
#   'status_notes': 'open',
#   'agency_responsible': 'Noise Report',
#   'service_name': 'Noise',
#   'service_subtype': 'other_excessive_noise',
#   'address': '1469 SACRAMENTO ST, SAN FRANCISCO, CA 94109',
#   'street': 'SACRAMENTO ST',
#   'supervisor_district': '3.0',
#   'neighborhoods_sffind_boundaries': 'Nob Hill',
#   'analysis_neighborhood': 'Nob Hill',
#   'police_district': 'CENTRAL',
#   'lat': '37.791916091988085',
#   'long': '-122.41712115705012',
#   'point': {'latitude': '37.791916091988085',
#    'longitude': '-122.41712115705012',
#    'human_address': '{"address": "", "city": "", "state": "", "zip": ""}'},
#   'point_geom': {'type': 'Point',
#    'coordinates': [-122.417121157, 37.791916092]},
#   'source': 'Mobile',
#   'data_as_of': '2026-06-15T01:00:00.000',
#   'data_loaded_at': '2026-06-15T03:13:26.000'},
#  {'service_request_id': '101004053643',
#   'requested_datetime': '2026-05-13T22:13:59.000',
#   'closed_date': '2026-06-13T04:11:00.000',
#   'updated_datetime': '2026-06-13T03:17:24.000',
#   'status_description': 'Closed',
#   'status_notes': 'Case Resolved - No Work Needed',
#   'agency_responsible': 'PW - Street and Environmental Services',
#   'service_name': 'Street and Sidewalk Cleaning',
#   'service_subtype': 'garbage_and_debris',
#   'service_details': 'other_loose_garbage_debris_yard_waste',
#   'address': '1475 15TH ST, SAN FRANCISCO, CA 94103',
#   'street': '15TH ST',
#   'supervisor_district': '9.0',
#   'neighborhoods_sffind_boundaries': 'Mission',
#   'analysis_neighborhood': 'Mission',
#   'police_district': 'MISSION',
#   'lat': '37.76677735',
#   'long': '-122.41719486',
#   'point': {'latitude': '37.76677735',
#    'longitude': '-122.41719486',
#    'human_address': '{"address": "", "city": "", "state": "", "zip": ""}'},
#   'point_geom': {'type': 'Point', 'coordinates': [-122.41719486, 37.76677735]},
#   'source': 'Web',
#   'media_url': {'url': 'https://sanfrancisco.form.us.empro.verintcloudservices.com/form/auto/download_attachments?caseid=101004053643&formref=A1E3VYA9'},
#   'data_as_of': '2026-06-15T01:00:00.000',
#   'data_loaded_at': '2026-06-15T03:13:26.000'},
#  {'service_request_id': '101004061128',
#   'requested_datetime': '2026-05-15T01:06:50.000',
#   'closed_date': '2026-06-13T04:26:31.000',
#   'updated_datetime': '2026-06-13T03:32:39.000',
#   'status_description': 'Closed',
#   'status_notes': 'Case Resolved - No Work Needed',
#   'agency_responsible': 'PW - Street and Environmental Services',
#   'service_name': 'Street and Sidewalk Cleaning',
#   'service_subtype': 'garbage_and_debris',
#   'service_details': 'other_loose_garbage_debris_yard_waste',
#   'address': '1807 FOLSOM ST, SAN FRANCISCO, CA 94103',
#   'street': 'FOLSOM ST',
#   'supervisor_district': '9.0',
#   'neighborhoods_sffind_boundaries': 'Mission',
#   'analysis_neighborhood': 'Mission',
#   'police_district': 'MISSION',
#   'lat': '37.76839064',
#   'long': '-122.4154186',
#   'point': {'latitude': '37.76839064',
#    'longitude': '-122.4154186',
#    'human_address': '{"address": "", "city": "", "state": "", "zip": ""}'},
#   'point_geom': {'type': 'Point', 'coordinates': [-122.4154186, 37.76839064]},
#   'source': 'Phone',
#   'data_as_of': '2026-06-15T01:00:00.000',
#   'data_loaded_at': '2026-06-15T03:13:26.000'},
#  {'service_request_id': '101004241496',
#   'requested_datetime': '2026-06-13T03:28:45.000',
#   'updated_datetime': '2026-06-13T03:37:13.000',
#   'status_description': 'Open',
#   'status_notes': 'open',
#   'agency_responsible': 'MTA - Muni Feedback Received',
#   'service_name': 'Muni Service Feedback',
#   'service_subtype': 'complaint_frequency_reliability',
#   'service_details': 'pass_ups',
#   'address': 'INTERSECTION MISSION ST, 9TH ST, SAN FRANCISCO, CA 94103',
#   'street': 'MISSION ST',
#   'supervisor_district': '6.0',
#   'neighborhoods_sffind_boundaries': 'South of Market',
#   'analysis_neighborhood': 'South of Market',
#   'police_district': 'SOUTHERN',
#   'lat': '37.7762305281',
#   'long': '-122.4147111681',
#   'point': {'latitude': '37.7762305281',
#    'longitude': '-122.4147111681',
#    'human_address': '{"address": "", "city": "", "state": "", "zip": ""}'},
#   'point_geom': {'type': 'Point',
#    'coordinates': [-122.414711168, 37.776230528]},
#   'source': 'Phone',
#   'data_as_of': '2026-06-15T01:00:00.000',
#   'data_loaded_at': '2026-06-15T03:13:26.000'},
#  {'service_request_id': '101004241497',
#   'requested_datetime': '2026-06-13T03:37:18.000',
#   'updated_datetime': '2026-06-13T03:37:28.000',
#   'status_description': 'Open',
#   'status_notes': 'open',
#   'agency_responsible': 'Noise Report',
#   'service_name': 'Noise',
#   'service_subtype': 'other_excessive_noise',
#   'address': '1672 15TH ST, SAN FRANCISCO, CA 94103',
#   'street': '15TH ST',
#   'supervisor_district': '9.0',
#   'neighborhoods_sffind_boundaries': 'Mission',
#   'analysis_neighborhood': 'Mission',
#   'police_district': 'MISSION',
#   'lat': '37.766690407037444',
#   'long': '-122.42154960441827',
#   'point': {'latitude': '37.766690407037444',
#    'longitude': '-122.42154960441827',
#    'human_address': '{"address": "", "city": "", "state": "", "zip": ""}'},
#   'point_geom': {'type': 'Point',
#    'coordinates': [-122.421549604, 37.766690407]},
#   'source': 'Mobile',
#   'data_as_of': '2026-06-15T01:00:00.000',
#   'data_loaded_at': '2026-06-15T03:13:26.000'},
#  {'service_request_id': '101004241498',
#   'requested_datetime': '2026-06-13T03:40:01.000',
#   'updated_datetime': '2026-06-13T03:40:08.000',
#   'status_description': 'Open',
#   'status_notes': 'open',
#   'agency_responsible': 'Noise Report',
#   'service_name': 'Noise',
#   'service_subtype': 'other_excessive_noise',
#   'address': '1758 31ST AVE, SAN FRANCISCO, CA 94122',
#   'street': '31ST AVE',
#   'supervisor_district': '4.0',
#   'neighborhoods_sffind_boundaries': 'Outer Sunset',
#   'analysis_neighborhood': 'Sunset/Parkside',
#   'police_district': 'TARAVAL',
#   'lat': '37.75445268954961',
#   'long': '-122.48907701271077',
#   'point': {'latitude': '37.75445268954961',
#    'longitude': '-122.48907701271077',
#    'human_address': '{"address": "", "city": "", "state": "", "zip": ""}'},
#   'point_geom': {'type': 'Point',
#    'coordinates': [-122.489077013, 37.75445269]},
#   'source': 'Mobile',
#   'data_as_of': '2026-06-15T01:00:00.000',
#   'data_loaded_at': '2026-06-15T03:13:26.000'},
#  {'service_request_id': '101004241285',
#   'requested_datetime': '2026-06-12T22:58:02.000',
#   'closed_date': '2026-06-13T04:48:02.000',
#   'updated_datetime': '2026-06-13T03:48:06.000',
#   'status_description': 'Closed',
#   'status_notes': 'Case Resolved - Officer responded to request under CAD # 261633985. Unable to Locate.',
#   'agency_responsible': 'MTA - Parking Enforcement Dispatch',
#   'service_name': 'Parking Enforcement',
#   'service_subtype': 'blocking_driveway_cite_tow',
#   'address': '1427 SHRADER ST, SAN FRANCISCO, CA 94117',
#   'street': 'SHRADER ST',
#   'supervisor_district': '8.0',
#   'neighborhoods_sffind_boundaries': 'Ashbury Heights',
#   'analysis_neighborhood': 'Haight Ashbury',
#   'police_district': 'PARK',
#   'lat': '37.76199666666665',
#   'long': '-122.45070499999999',
#   'point': {'latitude': '37.76199666666665',
#    'longitude': '-122.45070499999999',
#    'human_address': '{"address": "", "city": "", "state": "", "zip": ""}'},
#   'point_geom': {'type': 'Point', 'coordinates': [-122.450705, 37.761996667]},
#   'source': 'Mobile',
#   'media_url': {'url': 'https://spot-sf-res.cloudinary.com/image/upload/v1781330280/san-francisco/production/yehuu5pzgaw3x0gminfl.jpg'},
#   'data_as_of': '2026-06-15T01:00:00.000',
#   'data_loaded_at': '2026-06-15T03:13:26.000'},
#  {'service_request_id': '101004241502',
#   'requested_datetime': '2026-06-13T03:56:44.000',
#   'updated_datetime': '2026-06-13T03:56:54.000',
#   'status_description': 'Open',
#   'status_notes': 'open',
#   'agency_responsible': 'Entertainment Commission',
#   'service_name': 'Noise',
#   'service_subtype': 'entertainment',
#   'address': '33 CEDAR ST, SAN FRANCISCO, CA 94109',
#   'street': 'CEDAR ST',
#   'supervisor_district': '6.0',
#   'neighborhoods_sffind_boundaries': 'Lower Nob Hill',
#   'analysis_neighborhood': 'Tenderloin',
#   'police_district': 'NORTHERN',
#   'lat': '37.7864653580108',
#   'long': '-122.41871070116758',
# ...
#   'service_subtype': 'garbage_and_debris',
#   'service_details': 'city_garbage_can_overflowing',
#   'address': '207 FREDERICK ST, SAN FRANCISCO, CA 94117',
#   'street': 'FREDERICK ST',
#   'supervisor_district': '8.0',
#   'neighborhoods_sffind_boundaries': 'Ashbury Heights',
#   'analysis_neighborhood': 'Haight Ashbury',
#   'police_district': 'PARK',
#   'lat': '37.76714871',
#   'long': '-122.44648917',
#   'point': {'latitude': '37.76714871',
#    'longitude': '-122.44648917',
#    'human_address': '{"address": "", "city": "", "state": "", "zip": ""}'},
#   'point_geom': {'type': 'Point', 'coordinates': [-122.44648917, 37.76714871]},
#   'source': 'Web',
#   'media_url': {'url': 'https://sanfrancisco.form.us.empro.verintcloudservices.com/form/auto/download_attachments?caseid=101004242341&formref=FYF0OVE2'},
#   'data_as_of': '2026-06-15T01:00:00.000',
#   'data_loaded_at': '2026-06-15T03:13:26.000'},
#  {'service_request_id': '101004242464',
#   'requested_datetime': '2026-06-13T09:07:10.000',
#   'closed_date': '2026-06-13T10:51:04.000',
#   'updated_datetime': '2026-06-13T10:51:10.000',
#   'status_description': 'Closed',
#   'status_notes': 'Case Resolved',
#   'agency_responsible': 'Recology - Overflowing',
#   'service_name': 'Litter Receptacle Maintenance',
#   'service_subtype': 'debris_box_maintenance_overflowing',
#   'address': '1950 GOUGH ST, SAN FRANCISCO, CA 94109',
#   'street': 'GOUGH ST',
#   'supervisor_district': '2.0',
#   'neighborhoods_sffind_boundaries': 'Pacific Heights',
#   'analysis_neighborhood': 'Pacific Heights',
#   'police_district': 'NORTHERN',
#   'lat': '37.79156047',
#   'long': '-122.42578158',
#   'point': {'latitude': '37.79156047',
#    'longitude': '-122.42578158',
#    'human_address': '{"address": "", "city": "", "state": "", "zip": ""}'},
#   'point_geom': {'type': 'Point', 'coordinates': [-122.42578158, 37.79156047]},
#   'source': 'Web',
#   'data_as_of': '2026-06-15T01:00:00.000',
#   'data_loaded_at': '2026-06-15T03:13:26.000'},
#  {'service_request_id': '101004242508',
#   'requested_datetime': '2026-06-13T09:14:58.000',
#   'closed_date': '2026-06-13T10:51:08.000',
#   'updated_datetime': '2026-06-13T10:51:20.000',
#   'status_description': 'Closed',
#   'status_notes': 'Case Resolved',
#   'agency_responsible': 'Recology - Overflowing',
#   'service_name': 'Street and Sidewalk Cleaning',
#   'service_subtype': 'garbage_and_debris',
#   'service_details': 'city_garbage_can_overflowing',
#   'address': '2208 FILBERT ST, SAN FRANCISCO, CA 94123',
#   'street': 'FILBERT ST',
#   'supervisor_district': '2.0',
#   'neighborhoods_sffind_boundaries': 'Union Street',
#   'analysis_neighborhood': 'Marina',
#   'police_district': 'NORTHERN',
#   'lat': '37.79803941',
#   'long': '-122.43586232',
#   'point': {'latitude': '37.79803941',
#    'longitude': '-122.43586232',
#    'human_address': '{"address": "", "city": "", "state": "", "zip": ""}'},
#   'point_geom': {'type': 'Point', 'coordinates': [-122.43586232, 37.79803941]},
#   'source': 'Web',
#   'media_url': {'url': 'https://sanfrancisco.form.us.empro.verintcloudservices.com/form/auto/download_attachments?caseid=101004242508&formref=6620CQS2'},
#   'data_as_of': '2026-06-15T01:00:00.000',
#   'data_loaded_at': '2026-06-15T03:13:26.000'},
#  {'service_request_id': '101004242609',
#   'requested_datetime': '2026-06-13T09:33:51.000',
#   'closed_date': '2026-06-13T10:51:11.000',
#   'updated_datetime': '2026-06-13T10:51:20.000',
#   'status_description': 'Closed',
#   'status_notes': 'Case Resolved',
#   'agency_responsible': 'Recology - Overflowing',
#   'service_name': 'Street and Sidewalk Cleaning',
#   'service_subtype': 'garbage_and_debris',
#   'service_details': 'city_garbage_can_overflowing',
#   'address': 'INTERSECTION DE HARO ST, MARIPOSA ST, SAN FRANCISCO, CA 94107',
#   'street': 'DE HARO ST',
#   'supervisor_district': '10.0',
#   'neighborhoods_sffind_boundaries': 'Potrero Hill',
#   'analysis_neighborhood': 'Potrero Hill',
#   'police_district': 'BAYVIEW',
#   'lat': '37.763577794201616',
#   'long': '-122.40147789319678',
#   'point': {'latitude': '37.763577794201616',
#    'longitude': '-122.40147789319678',
#    'human_address': '{"address": "", "city": "", "state": "", "zip": ""}'},
#   'point_geom': {'type': 'Point',
#    'coordinates': [-122.401477893, 37.763577794]},
#   'source': 'Mobile',
#   'data_as_of': '2026-06-15T01:00:00.000',
#   'data_loaded_at': '2026-06-15T03:13:26.000'},
#  {'service_request_id': '101004242632',
#   'requested_datetime': '2026-06-13T09:36:37.000',
#   'closed_date': '2026-06-13T10:51:16.000',
#   'updated_datetime': '2026-06-13T10:51:24.000',
#   'status_description': 'Closed',
#   'status_notes': 'Case Resolved',
#   'agency_responsible': 'Recology - Overflowing',
#   'service_name': 'Street and Sidewalk Cleaning',
#   'service_subtype': 'garbage_and_debris',
#   'service_details': 'city_garbage_can_overflowing',
#   'address': 'INTERSECTION VAN NESS AVE, CHESTNUT ST, SAN FRANCISCO, CA 94109',
#   'street': 'VAN NESS AVE',
#   'supervisor_district': '3.0',
#   'neighborhoods_sffind_boundaries': 'Union Street',
#   'police_district': 'NORTHERN',
#   'source': 'Integrated Agency',
#   'data_as_of': '2026-06-15T01:00:00.000',
#   'data_loaded_at': '2026-06-15T03:13:26.000'},
#  {'service_request_id': '101004213841',
#   'requested_datetime': '2026-06-08T18:16:40.000',
#   'updated_datetime': '2026-06-13T10:51:35.000',
#   'status_description': 'Open',
#   'status_notes': 'open',
#   'agency_responsible': 'MTA - Muni Feedback Received',
#   'service_name': 'Muni Employee Feedback',
#   'service_subtype': 'complaint_unsafe_operation',
#   'service_details': 'customer_injury',
#   'address': 'INTERSECTION FILLMORE ST, GEARY BLVD, SAN FRANCISCO, CA 94115',
#   'street': 'FILLMORE ST',
#   'supervisor_district': '5.0',
#   'neighborhoods_sffind_boundaries': 'Japantown',
#   'analysis_neighborhood': 'Western Addition',
#   'police_district': 'NORTHERN',
#   'lat': '37.784354982',
#   'long': '-122.4329143004',
#   'point': {'latitude': '37.784354982',
#    'longitude': '-122.4329143004',
#    'human_address': '{"address": "", "city": "", "state": "", "zip": ""}'},
#   'point_geom': {'type': 'Point', 'coordinates': [-122.4329143, 37.784354982]},
#   'source': 'Phone',
#   'data_as_of': '2026-06-15T01:00:00.000',
#   'data_loaded_at': '2026-06-15T03:13:26.000'},
#  {'service_request_id': '101004242988',
#   'requested_datetime': '2026-06-13T10:40:41.000',
#   'closed_date': '2026-06-13T10:51:28.000',
#   'updated_datetime': '2026-06-13T10:51:40.000',
#   'status_description': 'Closed',
#   'status_notes': 'Case Resolved',
#   'agency_responsible': 'Recology - Abandoned',
#   'service_name': 'Street and Sidewalk Cleaning',
#   'service_subtype': 'garbage_and_debris',
#   'service_details': 'furniture',
#   'address': '2164 MISSION ST, SAN FRANCISCO, CA 94110',
#   'street': 'MISSION ST',
#   'supervisor_district': '9.0',
#   'neighborhoods_sffind_boundaries': 'Mission',
#   'analysis_neighborhood': 'Mission',
#   'police_district': 'MISSION',
#   'lat': '37.762457950312935',
#   'long': '-122.4194050580263',
#   'point': {'latitude': '37.762457950312935',
#    'longitude': '-122.4194050580263',
#    'human_address': '{"address": "", "city": "", "state": "", "zip": ""}'},
#   'point_geom': {'type': 'Point',
#    'coordinates': [-122.419405058, 37.76245795]},
#   'source': 'Mobile',
#   'media_url': {'url': 'https://spot-sf-res.cloudinary.com/image/upload/v1781372440/san-francisco/production/klbqqgyoblaphuzunsgc.jpg'},
#   'data_as_of': '2026-06-15T01:00:00.000',
#   'data_loaded_at': '2026-06-15T03:13:26.000'},
#  {'service_request_id': '101004242664',
#   'requested_datetime': '2026-06-13T09:42:32.000',
#   'closed_date': '2026-06-13T11:51:41.000',
#   'updated_datetime': '2026-06-13T10:51:44.000',
#   'status_description': 'Closed',
#   'status_notes': 'Case Resolved - Officer responded to request under CAD # 261640974.  Citation was issued.',
#   'agency_responsible': 'MTA - Parking Enforcement Dispatch',
#   'service_name': 'Parking Enforcement',
#   'service_subtype': 'blocking_driveway_cite_tow',
#   'address': '2035 FULTON ST, SAN FRANCISCO, CA 94117',
#   'street': 'FULTON ST',
#   'supervisor_district': '5.0',
#   'neighborhoods_sffind_boundaries': 'Panhandle',
#   'analysis_neighborhood': 'Lone Mountain/USF',
#   'police_district': 'PARK',
#   'lat': '37.775278953587154',
#   'long': '-122.45028656583912',
#   'point': {'latitude': '37.775278953587154',
#    'longitude': '-122.45028656583912',
#    'human_address': '{"address": "", "city": "", "state": "", "zip": ""}'},
#   'point_geom': {'type': 'Point',
#    'coordinates': [-122.450286566, 37.775278954]},
#   'source': 'Mobile',
#   'media_url': {'url': 'https://spot-sf-res.cloudinary.com/image/upload/v1781368951/san-francisco/production/iqm1oxtphradtmnglv5n.jpg'},
#   'data_as_of': '2026-06-15T01:00:00.000',
#   'data_loaded_at': '2026-06-15T03:13:26.000'},
#  {'service_request_id': '101004243001',
#   'requested_datetime': '2026-06-13T10:43:02.000',
#   'updated_datetime': '2026-06-13T10:52:32.000',
#   'status_description': 'Open',
#   'status_notes': 'accepted',
#   'agency_responsible': 'PW - Urban Forestry',
#   'service_name': 'Tree Maintenance',
#   'service_subtype': 'overgrown_tree',
#   'service_details': 'blocking_signs',
#   'address': '4006 26TH ST, SAN FRANCISCO, CA 94131',
#   'street': '26TH ST',
#   'supervisor_district': '8.0',
#   'neighborhoods_sffind_boundaries': 'Noe Valley',
#   'analysis_neighborhood': 'Noe Valley',
#   'police_district': 'MISSION',
#   'lat': '37.7484625',
#   'long': '-122.42979385',
#   'point': {'latitude': '37.7484625',
#    'longitude': '-122.42979385',
#    'human_address': '{"address": "", "city": "", "state": "", "zip": ""}'},
#   'point_geom': {'type': 'Point', 'coordinates': [-122.42979385, 37.7484625]},
#   'source': 'Phone',
#   'data_as_of': '2026-06-15T01:00:00.000',
#   'data_loaded_at': '2026-06-15T03:13:26.000'},
#  {'service_request_id': '101004242894',
#   'requested_datetime': '2026-06-13T10:24:40.000',
#   'closed_date': '2026-06-13T10:52:26.000',
#   'updated_datetime': '2026-06-13T10:52:34.000',
#   'status_description': 'Closed',
#   'status_notes': 'Case Resolved',
#   'agency_responsible': 'Recology - Abandoned',
#   'service_name': 'Street and Sidewalk Cleaning',
#   'service_subtype': 'garbage_and_debris',
#   'service_details': 'refrigerator_appliance',
#   'address': '2701 HARRISON ST, SAN FRANCISCO, CA 94110',
#   'street': 'HARRISON ST',
#   'supervisor_district': '9.0',
#   'neighborhoods_sffind_boundaries': 'Mission',
#   'analysis_neighborhood': 'Mission',
#   'police_district': 'MISSION',
#   'lat': '37.754139801074146',
#   'long': '-122.4120169132948',
#   'point': {'latitude': '37.754139801074146',
#    'longitude': '-122.4120169132948',
#    'human_address': '{"address": "", "city": "", "state": "", "zip": ""}'},
#   'point_geom': {'type': 'Point',
#    'coordinates': [-122.412016913, 37.754139801]},
#   'source': 'Mobile',
#   'media_url': {'url': 'https://spot-sf-res.cloudinary.com/image/upload/v1781371479/san-francisco/production/kw8evytysupj0nn7zqra.jpg'},
#   'data_as_of': '2026-06-15T01:00:00.000',
#   'data_loaded_at': '2026-06-15T03:13:26.000'},
#  {'service_request_id': '101004242950',
#   'requested_datetime': '2026-06-13T10:36:04.000',
#   'closed_date': '2026-06-13T10:52:29.000',
#   'updated_datetime': '2026-06-13T10:52:35.000',
#   'status_description': 'Closed',
#   'status_notes': 'Case Resolved',
#   'agency_responsible': 'Recology - Abandoned',
#   'service_name': 'Street and Sidewalk Cleaning',
#   'service_subtype': 'garbage_and_debris',
#   'service_details': 'other_bagged_boxed_contained_garbage',
#   'address': '2280 LOMBARD ST, SAN FRANCISCO, CA 94123',
#   'street': 'LOMBARD ST',
#   'supervisor_district': '2.0',
#   'neighborhoods_sffind_boundaries': 'Marina',
#   'analysis_neighborhood': 'Marina',
#   'police_district': 'NORTHERN',
#   'lat': '37.79960130139131',
#   'long': '-122.43897056741652',
#   'point': {'latitude': '37.79960130139131',
#    'longitude': '-122.43897056741652',
#    'human_address': '{"address": "", "city": "", "state": "", "zip": ""}'},
#   'point_geom': {'type': 'Point',
#    'coordinates': [-122.438970567, 37.799601301]},
#   'source': 'Mobile',
#   'media_url': {'url': 'https://spot-sf-res.cloudinary.com/image/upload/v1781372163/san-francisco/production/p1amy8blyjebg8foltrj.jpg'},
#   'data_as_of': '2026-06-15T01:00:00.000',
#   'data_loaded_at': '2026-06-15T03:13:26.000'},
#  {'service_request_id': '101004241969',
#   'requested_datetime': '2026-06-13T07:57:01.000',
#   'closed_date': '2026-06-13T11:45:53.000',
#   'updated_datetime': '2026-06-13T10:52:41.000',
#   'status_description': 'Closed',
#   'status_notes': 'Case Resolved - Resolved',
#   'agency_responsible': 'PW - Street and Environmental Services',
#   'service_name': 'Street and Sidewalk Cleaning',
#   'service_subtype': 'garbage_and_debris',
#   'service_details': 'other_loose_garbage_debris_yard_waste',
#   'address': 'INTERSECTION 18TH ST, VALENCIA ST, SAN FRANCISCO, CA 94110',
#   'street': '18TH ST',
#   'supervisor_district': '9.0',
#   'neighborhoods_sffind_boundaries': 'Mission',
#   'analysis_neighborhood': 'Mission',
#   'police_district': 'MISSION',
#   'lat': '37.76171752879702',
#   'long': '-122.42158919456197',
#   'point': {'latitude': '37.76171752879702',
#    'longitude': '-122.42158919456197',
#    'human_address': '{"address": "", "city": "", "state": "", "zip": ""}'},
#   'point_geom': {'type': 'Point',
#    'coordinates': [-122.421589195, 37.761717529]},
#   'source': 'Mobile',
#   'media_url': {'url': 'https://spot-sf-res.cloudinary.com/image/upload/v1781362620/san-francisco/production/vxp1qyy54rdwl4ifozmn.jpg'},
#   'data_as_of': '2026-06-15T01:00:00.000',
#   'data_loaded_at': '2026-06-15T03:13:26.000'},
#  {'service_request_id': '101004223503',
#   'requested_datetime': '2026-06-10T09:50:59.000',
#   'closed_date': '2026-06-13T11:45:26.000',
#   'updated_datetime': '2026-06-13T10:52:51.000',
#   'status_description': 'Closed',
#   'status_notes': 'Case Resolved - No Work Needed',
#   'agency_responsible': 'PW - Street and Environmental Services',
#   'service_name': 'Street and Sidewalk Cleaning',
#   'service_subtype': 'garbage_and_debris',
#   'service_details': 'other_loose_garbage_debris_yard_waste',
#   'address': '464 MENDELL ST, SAN FRANCISCO, CA 94124',
#   'street': 'MENDELL ST',
#   'supervisor_district': '10.0',
#   'neighborhoods_sffind_boundaries': 'Bayview',
#   'analysis_neighborhood': 'Bayview Hunters Point',
#   'police_district': 'BAYVIEW',
#   'lat': '37.74054242',
#   'long': '-122.3851433',
#   'point': {'latitude': '37.74054242',
#    'longitude': '-122.3851433',
#    'human_address': '{"address": "", "city": "", "state": "", "zip": ""}'},
#   'point_geom': {'type': 'Point', 'coordinates': [-122.3851433, 37.74054242]},
#   'source': 'Web',
#   'media_url': {'url': 'https://sanfrancisco.form.us.empro.verintcloudservices.com/form/auto/download_attachments?caseid=101004223503&formref=W3T3L4W6'},
#   'data_as_of': '2026-06-15T01:00:00.000',
#   'data_loaded_at': '2026-06-15T03:13:26.000'},
#  {'service_request_id': '101004208214',
#   'requested_datetime': '2026-06-08T06:06:55.000',
#   'closed_date': '2026-06-13T11:49:39.000',
#   'updated_datetime': '2026-06-13T10:52:54.000',
#   'status_description': 'Closed',
#   'status_notes': 'Case Resolved - No Work Needed',
#   'agency_responsible': 'PW - Street and Environmental Services',
#   'service_name': 'Street and Sidewalk Cleaning',
#   'service_subtype': 'garbage_and_debris',
#   'service_details': 'other_loose_garbage_debris_yard_waste',
#   'address': '849 ELLIS ST, SAN FRANCISCO, CA 94109',
#   'street': 'ELLIS ST',
#   'supervisor_district': '6.0',
#   'neighborhoods_sffind_boundaries': 'Tenderloin',
#   'analysis_neighborhood': 'Tenderloin',
#   'police_district': 'NORTHERN',
#   'lat': '37.78384706',
#   'long': '-122.42015594',
#   'point': {'latitude': '37.78384706',
#    'longitude': '-122.42015594',
#    'human_address': '{"address": "", "city": "", "state": "", "zip": ""}'},
#   'point_geom': {'type': 'Point', 'coordinates': [-122.42015594, 37.78384706]},
#   'source': 'Web',
#   'media_url': {'url': 'https://sanfrancisco.form.us.empro.verintcloudservices.com/form/auto/download_attachments?caseid=101004208214&formref=7KS9E0J7'},
#   'data_as_of': '2026-06-15T01:00:00.000',
#   'data_loaded_at': '2026-06-15T03:13:26.000'},
#  ...]
